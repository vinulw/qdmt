# %%
# %load_ext autoreload
# %autoreload 2

# %%
# do all necessary imports for this chapter
import matplotlib.pyplot as plt
import numpy as np
from ncon import ncon
from scipy.optimize import minimize
from scipy.sparse.linalg import eigs, LinearOperator, gmres
from scipy.linalg import svd, polar, null_space
from functools import partial
from time import time
from tutorialFunctions import createMPS, normalizeMPS, fixedPoints, rightOrthonormalize, mixedCanonical, expVal2Uniform, expVal2Mixed
from densityFunctions import traceDistance

# %%
def uniformToRho(A):
    l, r = fixedPoints(A)
    rho = ncon([l, A, A, A.conj(), A.conj(), r],
                 ((2, 1), (1, -3, 4), (4, -4, 6), (2, -1, 7), (7, -2, 8), (6, 8)))
    return rho

# %%
def gradCenterTerms(hTilde, A, l=None, r=None):
    """
    Calculate the value of the center terms.
    
        Parameters
        ----------
        hTilde : np.array (d, d, d, d)
            reduced Hamiltonian,
            ordered topLeft-topRight-bottomLeft-bottomRight.
        A : np.array (D, d, D)
            normalized MPS tensor with 3 legs,
            ordered left-bottom-right.
        l : np.array (D, D), optional
            left fixed point of transfermatrix,
            normalized.
        r : np.array (D, D), optional
            right fixed point of transfermatrix,
            normalized.
        
        Returns
        -------
        term1 : np.array (D, d, D)
            first term of gradient,
            ordered left-mid-right.
        term2 : np.array (D, d, D)
            second term of gradient,
            ordered left-mid-right.
    """
    
    # calculate fixed points if not supplied
    if l is None or r is None:
        l, r = fixedPoints(A)
        
    # calculate first contraction
    term1 = ncon((l, r, A, A, np.conj(A), hTilde), ([-1, 1], [5, 7], [1, 3, 2], [2, 4, 5], [-3, 6, 7], [3, 4, -2, 6]))
    
    # calculate second contraction
    term2 = ncon((l, r, A, A, np.conj(A), hTilde), ([6, 1], [5, -3], [1, 3, 2], [2, 4, 5], [6, 7, -1], [3, 4, 7, -2]))

    
    return term1, term2

# %%
def gradCenterTermsAA(A, l=None, r=None):
    if l is None or r is None:
        l, r = fixedPoints(A)
    
    # # Contraction to calculate TrAA
    # tensors = [l, A, A, A.conj(), A.conj(), r, l, A, A, A.conj(), A.conj(), r]
    # edges = [
    #     (1, 2), (2, 6, 10), (10, 12, 14), (1, 5, 7), (7, 11, 13), (14, 13),
    #     (4, 3), (3, 5, 8), (8, 11, 15), (4, 6, 9), (9, 12, 16), (15, 16)
    # ]
    
    tensors = [l, A, A, A.conj(), r, l, A, A, A.conj(), A.conj(), r]
    edges = [
        (-1, 2), (2, 6, 10), (10, 12, 14), (-3, 11, 13), (14, 13),
        (4, 3), (3, -2, 8), (8, 11, 15), (4, 6, 9), (9, 12, 16), (15, 16)
    ]
    term1 = ncon(tensors, edges)
    
    tensors = [l, A, A, A.conj(), r, l, A, A, A.conj(), A.conj(), r]
    edges = [
        (1, 2), (2, 6, 10), (10, 12, 14), (1, 5, -1), (14, -3),
        (4, 3), (3, 5, 8), (8, -2, 15), (4, 6, 9), (9, 12, 16), (15, 16)
    ]
    term2 = ncon(tensors, edges)
    
    tensors = [l, A, A, A.conj(), A.conj(), r, l, A, A, A.conj(), r]
    edges = [
        (1, 2), (2, -2, 10), (10, 12, 14), (1, 5, 7), (7, 11, 13), (14, 13),
        (-1, 3), (3, 5, 8), (8, 11, 15), (-3, 12, 16), (15, 16)
    ]
    term3 = ncon(tensors, edges)
    
    tensors = [l, A, A, A.conj(), A.conj(), r, l, A, A, A.conj(), r]
    edges = [
        (1, 2), (2, 6, 10), (10, -2, 14), (1, 5, 7), (7, 11, 13), (14, 13),
        (4, 3), (3, 5, 8), (8, 11, 15), (4, 6, -1), (15, -3)
    ]
    term4 = ncon(tensors, edges)
    
    return term1, term2, term3, term4

# %%
def reducedHamUniform(h, A, l=None, r=None):
    """
    Regularize Hamiltonian such that its expectation value is 0.
    
        Parameters
        ----------
        h : np.array (d, d, d, d)
            Hamiltonian that needs to be reduced,
            ordered topLeft-topRight-bottomLeft-bottomRight.
        A : np.array (D, d, D)
            normalized MPS tensor with 3 legs,
            ordered left-bottom-right.
        l : np.array (D, D), optional
            left fixed point of transfermatrix,
            normalized.
        r : np.array (D, D), optional
            right fixed point of transfermatrix,
            normalized.
            
        Returns
        -------
        hTilde : np.array (d, d, d, d)
            reduced Hamiltonian,
            ordered topLeft-topRight-bottomLeft-bottomRight.
    """
    
    d = A.shape[1]
    
    # calculate fixed points if not supplied
    if l is None or r is None:
        l, r = fixedPoints(A)
    
    # calculate expectation value
    e = np.real(expVal2Uniform(h, A, l, r))
    
    # substract from hamiltonian
    hTilde = h - e * ncon((np.eye(d), np.eye(d)), ([-1, -3], [-2, -4]))
    
    return hTilde

# %%
def EtildeRight(A, l, r, v):
    """
    Implement the action of (1 - Etilde) on a right vector v.
    
        Parameters
        ----------
        A : np.array (D, d, D)
            normalized MPS tensor with 3 legs,
            ordered left-bottom-right.
        l : np.array (D, D), optional
            left fixed point of transfermatrix,
            normalized.
        r : np.array (D, D), optional
            right fixed point of transfermatrix,
            normalized.
        v : np.array (D**2)
            right matrix of size (D, D) on which
            (1 - Etilde) acts,
            given as a vector of size (D**2,)
        
        Returns
        -------
        vNew : np.array (D**2)
            result of action of (1 - Etilde)
            on a right matrix,
            given as a vector of size (D**2,)
    """
    
    D = A.shape[0]
    
    # reshape to matrix
    v = v.reshape(D, D)
        
    # transfermatrix contribution
    transfer = ncon((A, np.conj(A), v), ([-1, 2, 1], [-2, 2, 3], [1, 3]))

    # fixed point contribution
    fixed = np.trace(l @ v) * r

    # sum these with the contribution of the identity
    vNew = v - transfer + fixed

    return vNew.reshape((D ** 2))

# %%
def RhUniform(hTilde, A, l=None, r=None):
    """
    Find the partial contraction for Rh.
    
        Parameters
        ----------
        hTilde : np.array (d, d, d, d)
            reduced Hamiltonian,
            ordered topLeft-topRight-bottomLeft-bottomRight,
            renormalized.
        A : np.array (D, d, D)
            normalized MPS tensor with 3 legs,
            ordered left-bottom-right.
        l : np.array (D, D), optional
            left fixed point of transfermatrix,
            normalized.
        r : np.array (D, D), optional
            right fixed point of transfermatrix,
            normalized.
        
        Returns
        -------
        Rh : np.array (D, D)
            result of contraction,
            ordered top-bottom.
    """
    
    D = A.shape[0]
    
    # if l, r not specified, find fixed points
    if l is None or r is None:
        l, r = fixedPoints(A)
    
    # construct b, which is the matrix to the right of (1 - E)^P in the figure above
    b = ncon((r, A, A, np.conj(A), np.conj(A), hTilde), ([4, 5], [-1, 2, 1], [1, 3, 4], [-2, 8, 7], [7, 6, 5], [2, 3, 8, 6]))
    
    # solve Ax = b for x
    A = LinearOperator((D ** 2, D ** 2), matvec=partial(EtildeRight, A, l, r))
    Rh = gmres(A, b.reshape(D ** 2))[0]
    
    return Rh.reshape((D, D))

# %%
def gradLeftTerms(hTilde, A, l=None, r=None):
    """
    Calculate the value of the left terms.
    
        Parameters
        ----------
        hTilde : np.array (d, d, d, d)
            reduced Hamiltonian,
            ordered topLeft-topRight-bottomLeft-bottomRight,
            renormalized.
        A : np.array (D, d, D)
            MPS tensor with 3 legs,
            ordered left-bottom-right.
        l : np.array (D, D), optional
            left fixed point of transfermatrix,
            normalized.
        r : np.array (D, D), optional
            right fixed point of transfermatrix,
            normalized.
        
        Returns
        -------
        leftTerms : np.array (D, d, D)
            left terms of gradient,
            ordered left-mid-right.
    """
    
    # if l, r not specified, find fixed points
    if l is None or r is None:
        l, r = fixedPoints(A)
    
    # calculate partial contraction
    Rh = RhUniform(hTilde, A, l, r)
    
    # calculate full contraction
    leftTerms = ncon((Rh, A, l), ([1, -3], [2, -2, 1], [-1, 2]))
    
    return leftTerms

# %%
def EtildeLeft(A, l, r, v):
    """
    Implement the action of (1 - Etilde) on a left vector v.
    
        Parameters
        ----------
        A : np.array (D, d, D)
            normalized MPS tensor with 3 legs,
            ordered left-bottom-right.
        l : np.array (D, D), optional
            left fixed point of transfermatrix,
            normalized.
        r : np.array (D, D), optional
            right fixed point of transfermatrix,
            normalized.
        v : np.array (D**2)
            left matrix of size (D, D) on which
            (1 - Etilde) acts,
            given as a vector of size (D**2,)
        
        Returns
        -------
        vNew : np.array (D**2)
            result of action of (1 - Etilde)
            on a left matrix,
            given as a vector of size (D**2,)
    """
    
    D = A.shape[0]
    
    # reshape to matrix
    v = v.reshape(D, D)

    # transfer matrix contribution
    transfer = ncon((v, A, np.conj(A)), ([3, 1], [1, 2, -2], [3, 2, -1]))

    # fixed point contribution
    fixed = np.trace(v @ r) * l

    # sum these with the contribution of the identity
    vNew = v - transfer + fixed

    return vNew.reshape((D ** 2))

# %%
def LhUniform(hTilde, A, l=None, r=None):
    """
    Find the partial contraction for Lh.
    
        Parameters
        ----------
        hTilde : np.array (d, d, d, d)
            reduced Hamiltonian,
            ordered topLeft-topRight-bottomLeft-bottomRight,
            renormalized.
        A : np.array (D, d, D)
            MPS tensor with 3 legs,
            ordered left-bottom-right.
        l : np.array (D, D), optional
            left fixed point of transfermatrix,
            normalized.
        r : np.array (D, D), optional
            right fixed point of transfermatrix,
            normalized.
        
        Returns
        -------
        Lh : np.array (D, D)
            result of contraction,
            ordered bottom-top.
    """
    
    D = A.shape[0]
    
    # if l, r not specified, find fixed points
    if l is None or r is None:
        l, r = fixedPoints(A)
    
    # construct b, which is the matrix to the right of (1 - E)^P in the figure above
    b = ncon((l, A, A, np.conj(A), np.conj(A), hTilde), ([5, 1], [1, 3, 2], [2, 4, -2], [5, 6, 7], [7, 8, -1], [3, 4, 6, 8]))    
    
    # solve Ax = b for x
    A = LinearOperator((D ** 2, D ** 2), matvec=partial(EtildeLeft, A, l, r)) 
    Lh = gmres(A, b.reshape(D ** 2))[0]
    
    return Lh.reshape((D, D))

# %%
def gradRightTerms(hTilde, A, l=None, r=None):
    """
    Calculate the value of the right terms.
    
        Parameters
        ----------
        hTilde : np.array (d, d, d, d)
            reduced Hamiltonian,
            ordered topLeft-topRight-bottomLeft-bottomRight,
            renormalized.
        A : np.array (D, d, D)
            MPS tensor with 3 legs,
            ordered left-bottom-right.
        l : np.array (D, D), optional
            left fixed point of transfermatrix,
            normalized.
        r : np.array (D, D), optional
            right fixed point of transfermatrix,
            normalized.
        
        Returns
        -------
        rightTerms : np.array (D, d, D)
            right terms of gradient,
            ordered left-mid-right.
    """
    
    # if l, r not specified, find fixed points
    if l is None or r is None:
        l, r = fixedPoints(A)
    
    # calculate partial contraction
    Lh = LhUniform(hTilde, A, l, r)
    
    # calculate full contraction
    rightTerms = ncon((Lh, A, r), ([-1, 1], [1, -2, 2], [2, -3]))
    
    return rightTerms

# %%
def gradient(h, A, l=None, r=None):
    """
    Calculate the gradient of the expectation value of h @ MPS A.
    
        Parameters
        ----------
        h : np.array (d, d, d, d)
            Hamiltonian,
            ordered topLeft-topRight-bottomLeft-bottomRight,
            renormalized.
        A : np.array (D, d, D)
            MPS tensor with 3 legs,
            ordered left-bottom-right.
        l : np.array (D, D), optional
            left fixed point of transfermatrix,
            normalized.
        r : np.array (D, D), optional
            right fixed point of transfermatrix,
            normalized.
        
        Returns
        -------
        grad : np.array (D, d, D)
            Gradient,
            ordered left-mid-right.
    """
    
    # if l, r not specified, find fixed points
    if l is None or r is None:
        l, r = fixedPoints(A)
        
    # renormalize Hamiltonian and A
    # hTilde = reducedHamUniform(h, A, l, r)
    # hTildeA = reducedHamUniform(rhoA, A, l, r)
    hTilde = h
    hA = uniformToRho(A)
        
    # find terms
    centerTerm1, centerTerm2 = gradCenterTerms(hTilde, A, l, r)
    leftTerms = gradLeftTerms(hTilde, A, l, r)
    rightTerms = gradRightTerms(hTilde, A, l, r)
    
    centerTermAA1, centerTermAA2, centerTermAA3, centerTermAA4 = gradCenterTermsAA(A, l, r)
    leftTermsA = 2*gradLeftTerms(hA, A, l, r)
    rightTermsA = 2*gradRightTerms(hA, A, l, r)
    
    # grad = (centerTerm1A + centerTerm2A + leftTermsA + rightTermsA)

    grad = centerTermAA1 + centerTermAA2 + centerTermAA3 + centerTermAA4 + leftTermsA + rightTermsA
    # grad -= 2 * (centerTerm1 + centerTerm2)
    grad -= 2 * (centerTerm1 + centerTerm2 + leftTerms + rightTerms)
    
#     AAterms = centerTermAA1 + centerTermAA2 + centerTermAA3 + centerTermAA4
#     ABterms = centerTerm1 + centerTerm2# + leftTerms + rightTerms
#     print('AA Terms')
#     print(AAterms)
#     print()
#     print('AB Terms')
#     print(ABterms)
#     print()
#     print('AA Terms - AB Terms')
#     print(AAterms - 2*ABterms)
    
    return grad

# %%
def optimiseDensityGradDescent(h, D, eps=1e-1, A0=None, tol=1e-4, maxIter=1e4, verbose=True):
    """
    Find the ground state using gradient descent.
    
        Parameters
        ----------
        h : np.array (d, d, d, d)
            Hamiltonian to minimize,
            ordered topLeft-topRight-bottomLeft-bottomRight.
        D : int
            Bond dimension
        eps : float
            Stepsize.
        A0 : np.array (D, d, D)
            normalized MPS tensor with 3 legs,
            ordered left-bottom-right,
            initial guess.
        tol : float
            Tolerance for convergence criterium.
        
        Returns
        -------
        E : float
            expectation value @ minimum
        A : np.array (D, d, D)
            ground state MPS,
            ordered left-mid-right.
    """
    
    d = h.shape[0]
    
    # if no initial value, choose random
    if A0 is None:
        A0 = createMPS(D, d)
        A0 = normalizeMPS(A0)
    
    # calculate gradient
    g = gradient(h, A0)
    
    A = A0
    
    i = 0
    
    while not(np.linalg.norm(g) < tol):
        # do a step
        A = A - eps * g
        A = normalizeMPS(A)
        i += 1
        
        if verbose and not(i % 50):
            #E = np.real(expVal2Uniform(h, A))
            rhoA = uniformToRho(A)
            E = traceDistance(h, rhoA)
            print('iteration:\t{:d}\tdist:\t{:.12f}\tgradient norm:\t{:.4e}'.format(i, E, np.linalg.norm(g)))
        
        # calculate new gradient
        g = gradient(h, A)
        
        if i > maxIter:
            print('Warning: gradient descent did not converge!')
            break
    
    # calculate ground state energy
    # E = np.real(expVal2Uniform(h, A))
    rhoA = uniformToRho(A)
    E = traceDistance(h, rhoA)   
    
    return E, A

# %%
# Prepare state to optimise
d0, D0 = 2, 2
A0 = createMPS(D0, d0)
A0 = normalizeMPS(A0)

h = uniformToRho(A0)

# %%
d, D = 2, 2
A = createMPS(D, d)
A = normalizeMPS(A)
#A = A0

print('Gradient descent optimization:\n')
t0 = time()
E1, A1 = optimiseDensityGradDescent(h, D, eps=1e-1, A0=A, tol=1e-5, maxIter=1e4)
print('Time until convergence:', time()-t0, 's')
print('Computed trace dist:', E1, '\n')
# Out:
# Gradient descent optimization:
#
# iteration:	50	dist:	0.003447720699	gradient norm:	3.0961e-02
# iteration:	100	dist:	0.000411001688	gradient norm:	1.2411e-02
# iteration:	150	dist:	0.000122853808	gradient norm:	1.1957e-02
# iteration:	200	dist:	0.000084466700	gradient norm:	1.0712e-02
# iteration:	250	dist:	0.000069510532	gradient norm:	9.5633e-03
# iteration:	300	dist:	0.000059514846	gradient norm:	8.6217e-03
# iteration:	350	dist:	0.000051981365	gradient norm:	7.8426e-03
# iteration:	400	dist:	0.000046080327	gradient norm:	7.1870e-03
# iteration:	450	dist:	0.000041349196	gradient norm:	6.6274e-03
# iteration:	500	dist:	0.000037486835	gradient norm:	6.1438e-03
# iteration:	550	dist:	0.000034285685	gradient norm:	5.7216e-03
# iteration:	600	dist:	0.000031597860	gradient norm:	5.3497e-03
# iteration:	650	dist:	0.000029315330	gradient norm:	5.0196e-03
# iteration:	700	dist:	0.000027357533	gradient norm:	4.7246e-03
# iteration:	750	dist:	0.000025663311	gradient norm:	4.4593e-03
# iteration:	800	dist:	0.000024185499	gradient norm:	4.2194e-03
# iteration:	850	dist:	0.000022887215	gradient norm:	4.0014e-03
# iteration:	900	dist:	0.000021739254	gradient norm:	3.8025e-03
# iteration:	950	dist:	0.000020718227	gradient norm:	3.6202e-03
# iteration:	1000	dist:	0.000019805210	gradient norm:	3.4525e-03
# iteration:	1050	dist:	0.000018984749	gradient norm:	3.2977e-03
# iteration:	1100	dist:	0.000018244115	gradient norm:	3.1544e-03
# iteration:	1150	dist:	0.000017572739	gradient norm:	3.0214e-03
# iteration:	1200	dist:	0.000016961783	gradient norm:	2.8976e-03
# iteration:	1250	dist:	0.000016403808	gradient norm:	2.7820e-03
# iteration:	1300	dist:	0.000015892510	gradient norm:	2.6739e-03
# iteration:	1350	dist:	0.000015422519	gradient norm:	2.5726e-03
# iteration:	1400	dist:	0.000014989234	gradient norm:	2.4775e-03
# iteration:	1450	dist:	0.000014588693	gradient norm:	2.3879e-03
# iteration:	1500	dist:	0.000014217469	gradient norm:	2.3035e-03
# iteration:	1550	dist:	0.000013872582	gradient norm:	2.2237e-03
# iteration:	1600	dist:	0.000013551434	gradient norm:	2.1483e-03
# iteration:	1650	dist:	0.000013251747	gradient norm:	2.0769e-03
# iteration:	1700	dist:	0.000012971518	gradient norm:	2.0091e-03
# iteration:	1750	dist:	0.000012708979	gradient norm:	1.9448e-03
# iteration:	1800	dist:	0.000012462564	gradient norm:	1.8836e-03
# iteration:	1850	dist:	0.000012230882	gradient norm:	1.8253e-03
# iteration:	1900	dist:	0.000012012694	gradient norm:	1.7698e-03
# iteration:	1950	dist:	0.000011806893	gradient norm:	1.7168e-03
# iteration:	2000	dist:	0.000011612486	gradient norm:	1.6662e-03
# iteration:	2050	dist:	0.000011428581	gradient norm:	1.6178e-03
# iteration:	2100	dist:	0.000011254375	gradient norm:	1.5715e-03
# iteration:	2150	dist:	0.000011089143	gradient norm:	1.5271e-03
# iteration:	2200	dist:	0.000010932228	gradient norm:	1.4845e-03
# iteration:	2250	dist:	0.000010783035	gradient norm:	1.4437e-03
# iteration:	2300	dist:	0.000010641024	gradient norm:	1.4045e-03
# iteration:	2350	dist:	0.000010505700	gradient norm:	1.3668e-03
# iteration:	2400	dist:	0.000010376616	gradient norm:	1.3306e-03
# iteration:	2450	dist:	0.000010253360	gradient norm:	1.2957e-03
# iteration:	2500	dist:	0.000010135555	gradient norm:	1.2621e-03
# iteration:	2550	dist:	0.000010022856	gradient norm:	1.2297e-03
# iteration:	2600	dist:	0.000009914947	gradient norm:	1.1985e-03
# iteration:	2650	dist:	0.000009811534	gradient norm:	1.1684e-03
# iteration:	2700	dist:	0.000009712349	gradient norm:	1.1393e-03
# iteration:	2750	dist:	0.000009617144	gradient norm:	1.1112e-03
# iteration:	2800	dist:	0.000009525688	gradient norm:	1.0841e-03
# iteration:	2850	dist:	0.000009437769	gradient norm:	1.0578e-03
# iteration:	2900	dist:	0.000009353190	gradient norm:	1.0324e-03
# iteration:	2950	dist:	0.000009271768	gradient norm:	1.0078e-03
# iteration:	3000	dist:	0.000009193332	gradient norm:	9.8403e-04
# iteration:	3050	dist:	0.000009117724	gradient norm:	9.6096e-04
# iteration:	3100	dist:	0.000009044798	gradient norm:	9.3860e-04
# iteration:	3150	dist:	0.000008974414	gradient norm:	9.1691e-04
# iteration:	3200	dist:	0.000008906446	gradient norm:	8.9587e-04
# iteration:	3250	dist:	0.000008840772	gradient norm:	8.7545e-04
# iteration:	3300	dist:	0.000008777281	gradient norm:	8.5563e-04
# iteration:	3350	dist:	0.000008715867	gradient norm:	8.3637e-04
# iteration:	3400	dist:	0.000008656432	gradient norm:	8.1766e-04
# iteration:	3450	dist:	0.000008598882	gradient norm:	7.9947e-04
# iteration:	3500	dist:	0.000008543132	gradient norm:	7.8179e-04
# iteration:	3550	dist:	0.000008489099	gradient norm:	7.6459e-04
# iteration:	3600	dist:	0.000008436707	gradient norm:	7.4786e-04
# iteration:	3650	dist:	0.000008385882	gradient norm:	7.3157e-04
# iteration:	3700	dist:	0.000008336557	gradient norm:	7.1571e-04
# iteration:	3750	dist:	0.000008288667	gradient norm:	7.0027e-04
# iteration:	3800	dist:	0.000008242151	gradient norm:	6.8523e-04
# iteration:	3850	dist:	0.000008196952	gradient norm:	6.7057e-04
# iteration:	3900	dist:	0.000008153015	gradient norm:	6.5628e-04
# iteration:	3950	dist:	0.000008110289	gradient norm:	6.4234e-04
# iteration:	4000	dist:	0.000008068726	gradient norm:	6.2876e-04
# iteration:	4050	dist:	0.000008028278	gradient norm:	6.1550e-04
# iteration:	4100	dist:	0.000007988902	gradient norm:	6.0257e-04
# iteration:	4150	dist:	0.000007950558	gradient norm:	5.8995e-04
# iteration:	4200	dist:	0.000007913204	gradient norm:	5.7763e-04
# iteration:	4250	dist:	0.000007876804	gradient norm:	5.6559e-04
# iteration:	4300	dist:	0.000007841323	gradient norm:	5.5384e-04
# iteration:	4350	dist:	0.000007806725	gradient norm:	5.4236e-04
# iteration:	4400	dist:	0.000007772980	gradient norm:	5.3115e-04
# iteration:	4450	dist:	0.000007740055	gradient norm:	5.2019e-04
# iteration:	4500	dist:	0.000007707923	gradient norm:	5.0947e-04
# iteration:	4550	dist:	0.000007676554	gradient norm:	4.9899e-04
# iteration:	4600	dist:	0.000007645923	gradient norm:	4.8875e-04
# iteration:	4650	dist:	0.000007616004	gradient norm:	4.7873e-04
# iteration:	4700	dist:	0.000007586773	gradient norm:	4.6892e-04
# iteration:	4750	dist:	0.000007558206	gradient norm:	4.5933e-04
# iteration:	4800	dist:	0.000007530281	gradient norm:	4.4995e-04
# iteration:	4850	dist:	0.000007502978	gradient norm:	4.4076e-04
# iteration:	4900	dist:	0.000007476275	gradient norm:	4.3176e-04
# iteration:	4950	dist:	0.000007450154	gradient norm:	4.2296e-04
# iteration:	5000	dist:	0.000007424595	gradient norm:	4.1433e-04
# iteration:	5050	dist:	0.000007399581	gradient norm:	4.0589e-04
# iteration:	5100	dist:	0.000007375095	gradient norm:	3.9761e-04
# iteration:	5150	dist:	0.000007351121	gradient norm:	3.8950e-04
# iteration:	5200	dist:	0.000007327642	gradient norm:	3.8156e-04
# iteration:	5250	dist:	0.000007304644	gradient norm:	3.7377e-04
# iteration:	5300	dist:	0.000007282112	gradient norm:	3.6614e-04
# iteration:	5350	dist:	0.000007260032	gradient norm:	3.5866e-04
# iteration:	5400	dist:	0.000007238391	gradient norm:	3.5132e-04
# iteration:	5450	dist:	0.000007217176	gradient norm:	3.4413e-04
# iteration:	5500	dist:	0.000007196374	gradient norm:	3.3707e-04
# iteration:	5550	dist:	0.000007175975	gradient norm:	3.3015e-04
# iteration:	5600	dist:	0.000007155965	gradient norm:	3.2336e-04
# iteration:	5650	dist:	0.000007136334	gradient norm:	3.1670e-04
# iteration:	5700	dist:	0.000007117073	gradient norm:	3.1017e-04
# iteration:	5750	dist:	0.000007098169	gradient norm:	3.0376e-04
# iteration:	5800	dist:	0.000007079614	gradient norm:	2.9746e-04
# iteration:	5850	dist:	0.000007061398	gradient norm:	2.9128e-04
# iteration:	5900	dist:	0.000007043512	gradient norm:	2.8522e-04
# iteration:	5950	dist:	0.000007025946	gradient norm:	2.7926e-04
# iteration:	6000	dist:	0.000007008693	gradient norm:	2.7342e-04
# iteration:	6050	dist:	0.000006991744	gradient norm:	2.6768e-04
# iteration:	6100	dist:	0.000006975092	gradient norm:	2.6204e-04
# iteration:	6150	dist:	0.000006958728	gradient norm:	2.5650e-04
# iteration:	6200	dist:	0.000006942645	gradient norm:	2.5106e-04
# iteration:	6250	dist:	0.000006926836	gradient norm:	2.4572e-04
# iteration:	6300	dist:	0.000006911294	gradient norm:	2.4047e-04
# iteration:	6350	dist:	0.000006896012	gradient norm:	2.3531e-04
# iteration:	6400	dist:	0.000006880984	gradient norm:	2.3024e-04
# iteration:	6450	dist:	0.000006866204	gradient norm:	2.2526e-04
# iteration:	6500	dist:	0.000006851664	gradient norm:	2.2037e-04
# iteration:	6550	dist:	0.000006837361	gradient norm:	2.1555e-04
# iteration:	6600	dist:	0.000006823287	gradient norm:	2.1082e-04
# iteration:	6650	dist:	0.000006809438	gradient norm:	2.0618e-04
# iteration:	6700	dist:	0.000006795807	gradient norm:	2.0161e-04
# iteration:	6750	dist:	0.000006782391	gradient norm:	1.9711e-04
# iteration:	6800	dist:	0.000006769183	gradient norm:	1.9269e-04
# iteration:	6850	dist:	0.000006756179	gradient norm:	1.8835e-04
# iteration:	6900	dist:	0.000006743374	gradient norm:	1.8408e-04
# iteration:	6950	dist:	0.000006730764	gradient norm:	1.7988e-04
# iteration:	7000	dist:	0.000006718372	gradient norm:	1.7562e-04
# iteration:	7050	dist:	0.000006706120	gradient norm:	1.7168e-04
# iteration:	7100	dist:	0.000006694066	gradient norm:	1.6769e-04
# iteration:	7150	dist:	0.000006682190	gradient norm:	1.6376e-04
# iteration:	7200	dist:	0.000006670489	gradient norm:	1.5989e-04
# iteration:	7250	dist:	0.000006658957	gradient norm:	1.5609e-04
# iteration:	7300	dist:	0.000006647591	gradient norm:	1.5235e-04
# iteration:	7350	dist:	0.000006636388	gradient norm:	1.4866e-04
# iteration:	7400	dist:	0.000006625344	gradient norm:	1.4504e-04
# iteration:	7450	dist:	0.000006614455	gradient norm:	1.4148e-04
# iteration:	7500	dist:	0.000006603718	gradient norm:	1.3797e-04
# iteration:	7550	dist:	0.000006593130	gradient norm:	1.3452e-04
# iteration:	7600	dist:	0.000006582689	gradient norm:	1.3113e-04
# iteration:	7650	dist:	0.000006572390	gradient norm:	1.2779e-04
# iteration:	7700	dist:	0.000006562230	gradient norm:	1.2450e-04
# iteration:	7750	dist:	0.000006552208	gradient norm:	1.2127e-04
# iteration:	7800	dist:	0.000006542319	gradient norm:	1.1809e-04
# iteration:	7850	dist:	0.000006532562	gradient norm:	1.1496e-04
# iteration:	7900	dist:	0.000006522934	gradient norm:	1.1188e-04
# iteration:	7950	dist:	0.000006513431	gradient norm:	1.0885e-04
# iteration:	8000	dist:	0.000006504053	gradient norm:	1.0587e-04
# iteration:	8050	dist:	0.000006494795	gradient norm:	1.0294e-04
# iteration:	8100	dist:	0.000006485655	gradient norm:	1.0005e-04
# iteration:	8150	dist:	0.000006476635	gradient norm:	9.7107e-05
# iteration:	8200	dist:	0.000006467718	gradient norm:	9.4415e-05
# iteration:	8250	dist:	0.000006458921	gradient norm:	9.1679e-05
# iteration:	8300	dist:	0.000006450233	gradient norm:	8.8980e-05
# iteration:	8350	dist:	0.000006441653	gradient norm:	8.6326e-05
# iteration:	8400	dist:	0.000006433178	gradient norm:	8.3716e-05
# iteration:	8450	dist:	0.000006424806	gradient norm:	8.1151e-05
# iteration:	8500	dist:	0.000006416536	gradient norm:	7.8629e-05
# iteration:	8550	dist:	0.000006408365	gradient norm:	7.6152e-05
# iteration:	8600	dist:	0.000006400292	gradient norm:	7.3718e-05
# iteration:	8650	dist:	0.000006392315	gradient norm:	7.1327e-05
# iteration:	8700	dist:	0.000006384432	gradient norm:	6.8980e-05
# iteration:	8750	dist:	0.000006376641	gradient norm:	6.6676e-05
# iteration:	8800	dist:	0.000006368940	gradient norm:	6.4416e-05
# iteration:	8850	dist:	0.000006361328	gradient norm:	6.2200e-05
# iteration:	8900	dist:	0.000006353804	gradient norm:	6.0027e-05
# iteration:	8950	dist:	0.000006346365	gradient norm:	5.7899e-05
# iteration:	9000	dist:	0.000006339010	gradient norm:	5.5815e-05
# iteration:	9050	dist:	0.000006331738	gradient norm:	5.3777e-05
# iteration:	9100	dist:	0.000006324547	gradient norm:	5.1784e-05
# iteration:	9150	dist:	0.000006317435	gradient norm:	4.9839e-05
# iteration:	9200	dist:	0.000006310402	gradient norm:	4.7942e-05
# iteration:	9250	dist:	0.000006303446	gradient norm:	4.6093e-05
# iteration:	9300	dist:	0.000006296565	gradient norm:	4.4296e-05
# iteration:	9350	dist:	0.000006289758	gradient norm:	4.2551e-05
# iteration:	9400	dist:	0.000006283024	gradient norm:	4.0861e-05
# iteration:	9450	dist:	0.000006276361	gradient norm:	3.9227e-05
# iteration:	9500	dist:	0.000006269769	gradient norm:	3.7652e-05
# iteration:	9550	dist:	0.000006263247	gradient norm:	3.6139e-05
# iteration:	9600	dist:	0.000006256792	gradient norm:	3.4691e-05
# iteration:	9650	dist:	0.000006250404	gradient norm:	3.3313e-05
# iteration:	9700	dist:	0.000006244081	gradient norm:	3.2006e-05
# iteration:	9750	dist:	0.000006237823	gradient norm:	3.0778e-05
# iteration:	9800	dist:	0.000006231628	gradient norm:	2.9630e-05
# iteration:	9850	dist:	0.000006225496	gradient norm:	2.8569e-05
# iteration:	9900	dist:	0.000006219425	gradient norm:	2.7600e-05
# iteration:	9950	dist:	0.000006213415	gradient norm:	2.6726e-05
# iteration:	10000	dist:	0.000006207464	gradient norm:	2.5954e-05
# Warning: gradient descent did not converge!
# Time until convergence: 103.99145913124084 s
# Computed trace dist: 6.207345298809829e-06

# %% [markdown]
# ---
# ## Testing $Tr(\rho_A \rho_B)$
#
# Want to make sure that the construction using tensor networks is the same as the construction using standard matrices.

# %%
d, D = 2, 4
A = createMPS(D, d)
A = normalizeMPS(A)

B = createMPS(D, d)
B = normalizeMPS(B)

rhoA = uniformToRho(A).reshape(d**2, d**2)
rhoB = uniformToRho(B).reshape(d**2, d**2)

TrAB = np.trace(rhoA @ rhoB)

# %%
TrAB

# %%
def tensorTrAB(A, B):
    
    lA, rA = fixedPoints(A)
    lB, rB = fixedPoints(B)
    tensors = [lB, B, B, B.conj(), B.conj(), rB, lA, A, A, A.conj(), A.conj(), rA]
    edges = [
        (1, 2), (2, 6, 10), (10, 12, 14), (1, 5, 7), (7, 11, 13), (14, 13),
        (4, 3), (3, 5, 8), (8, 11, 15), (4, 6, 9), (9, 12, 16), (15, 16)
    ]
    
    return ncon(tensors, edges)

# %%
TrAB_tensor = tensorTrAB(A, B)

# %%
TrAB_tensor

# %%
print(np.allclose(TrAB, TrAB_tensor))

# %%
traceDistExact = traceDistance(rhoA.reshape(d, d, d, d), rhoB.reshape(d, d, d, d))
traceDistExact

# %%
traceDist_Tensor = tensorTrAB(A, A) + tensorTrAB(B, B) - 2*tensorTrAB(A, B)
traceDist_Tensor

# %%
np.allclose(traceDistExact, traceDist_Tensor)

# %% [markdown]
# ## Verify gradient is `0` when `A == B`

# %%
d, D = 2, 4
A = createMPS(D, d)
A = normalizeMPS(A)

rhoA = uniformToRho(A)

# %%
gradient(rhoA, A)
# Out:
# array([[[-1.11022302e-16-2.22044605e-16j,
#           0.00000000e+00+0.00000000e+00j,
#          -2.22044605e-16-2.22044605e-16j,
#          -1.11022302e-16-2.22044605e-16j],
#         [ 0.00000000e+00+0.00000000e+00j,
#           0.00000000e+00+0.00000000e+00j,
#          -2.22044605e-16-4.44089210e-16j,
#           0.00000000e+00+0.00000000e+00j]],
#
#        [[-1.11022302e-16-2.22044605e-16j,
#          -2.22044605e-16+0.00000000e+00j,
#           0.00000000e+00-2.22044605e-16j,
#          -1.11022302e-16-2.22044605e-16j],
#         [-2.22044605e-16+0.00000000e+00j,
#           2.22044605e-16-1.11022302e-16j,
#           0.00000000e+00-2.22044605e-16j,
#           0.00000000e+00+0.00000000e+00j]],
#
#        [[ 0.00000000e+00-1.11022302e-16j,
#          -1.11022302e-16-2.22044605e-16j,
#           0.00000000e+00-2.22044605e-16j,
#          -1.11022302e-16+2.22044605e-16j],
#         [ 0.00000000e+00-1.11022302e-16j,
#          -2.22044605e-16+0.00000000e+00j,
#           0.00000000e+00-2.22044605e-16j,
#           0.00000000e+00-2.22044605e-16j]],
#
#        [[ 0.00000000e+00-1.11022302e-16j,
#          -2.22044605e-16-5.55111512e-17j,
#           0.00000000e+00-1.11022302e-16j,
#           0.00000000e+00-2.22044605e-16j],
#         [ 0.00000000e+00-8.32667268e-17j,
#           0.00000000e+00-5.55111512e-17j,
#           0.00000000e+00-8.32667268e-17j,
#          -2.22044605e-16-2.22044605e-16j]]])

# %%
np.linalg.norm(_)
# Out:
# 1.1989637652951122e-15

# %% [markdown]
# ## Verify left and right gradient terms for $Tr \rho_A \rho_A$

# %%
def EtildeRight(A, l, r, v):
    """
    Implement the action of (1 - Etilde) on a right vector v.
    
        Parameters
        ----------
        A : np.array (D, d, D)
            normalized MPS tensor with 3 legs,
            ordered left-bottom-right.
        l : np.array (D, D), optional
            left fixed point of transfermatrix,
            normalized.
        r : np.array (D, D), optional
            right fixed point of transfermatrix,
            normalized.
        v : np.array (D**2)
            right matrix of size (D, D) on which
            (1 - Etilde) acts,
            given as a vector of size (D**2,)
        
        Returns
        -------
        vNew : np.array (D**2)
            result of action of (1 - Etilde)
            on a right matrix,
            given as a vector of size (D**2,)
    """
    
    D = A.shape[0]
    
    # reshape to matrix
    v = v.reshape(D, D)
        
    # transfermatrix contribution
    transfer = ncon((A, np.conj(A), v), ([-1, 2, 1], [-2, 2, 3], [1, 3]))

    # fixed point contribution
    fixed = np.trace(l @ v) * r

    # sum these with the contribution of the identity
    vNew = v - transfer + fixed

    return vNew.reshape((D ** 2))

# %%
def EtildeRightInner(A, l, r, v):
    """
    Implement the action of (1 - Etilde) on a right vector v.
    
        Parameters
        ----------
        A : np.array (D, d, D)
            normalized MPS tensor with 3 legs,
            ordered left-bottom-right.
        l : np.array (D, D), optional
            left fixed point of transfermatrix,
            normalized.
        r : np.array (D, D), optional
            right fixed point of transfermatrix,
            normalized.
        v : np.array (D**2)
            right matrix of size (D, D) on which
            (1 - Etilde) acts,
            given as a vector of size (D**2,)
        
        Returns
        -------
        vNew : np.array (D**2)
            result of action of (1 - Etilde)
            on a right matrix,
            given as a vector of size (D**2,)
    """
    
    D = A.shape[0]
    
    # reshape to matrix
    v = v.reshape(D, D)
        
    # transfermatrix contribution
    transfer = ncon((np.conj(A), A, v), ([-1, 2, 1], [-2, 2, 3], [1, 3]))

    # fixed point contribution
    fixed = np.trace(l.T @ v) * r.T

    # sum these with the contribution of the identity
    vNew = v - transfer + fixed

    return vNew.reshape((D ** 2))

# %%
def RhAUniform(A, l=None, r=None):
    """
    Find the partial contraction for Rh.
    
        Parameters
        ----------
        hTilde : np.array (d, d, d, d)
            reduced Hamiltonian,
            ordered topLeft-topRight-bottomLeft-bottomRight,
            renormalized.
        A : np.array (D, d, D)
            normalized MPS tensor with 3 legs,
            ordered left-bottom-right.
        l : np.array (D, D), optional
            left fixed point of transfermatrix,
            normalized.
        r : np.array (D, D), optional
            right fixed point of transfermatrix,
            normalized.
        
        Returns
        -------
        Rh : np.array (D, D)
            result of contraction,
            ordered top-bottom.
    """
    
    D = A.shape[0]
    
    # if l, r not specified, find fixed points
    if l is None or r is None:
        l, r = fixedPoints(A)
    
    # construct b, which is the matrix to the right of (1 - E)^P in the figure above
    #b = ncon((r, A, A, np.conj(A), np.conj(A), hTilde), ([4, 5], [-1, 2, 1], [1, 3, 4], [-2, 8, 7], [7, 6, 5], [2, 3, 8, 6]))
    b = ncon((l, A, A, np.conj(A), np.conj(A), np.conj(A), np.conj(A), A, A, r, r), 
            ([1, 2], [-1, 3, 5], [5, 9, 11], [-2, 4, 8], [8, 10, 14], 
             [1, 3, 6], [6, 9, 12], [2, 4, 7], [7, 10, 13], [13, 12], [11, 14]))
    
    # solve Ax = b for x
    A = LinearOperator((D ** 2, D ** 2), matvec=partial(EtildeRight, A, l, r))
    Rh = gmres(A, b.reshape(D ** 2))[0]
    
    return Rh.reshape((D, D))

# %%
def RhAUniformInner(A, l=None, r=None):
    """
    Find the partial contraction for Rh.
    
        Parameters
        ----------
        hTilde : np.array (d, d, d, d)
            reduced Hamiltonian,
            ordered topLeft-topRight-bottomLeft-bottomRight,
            renormalized.
        A : np.array (D, d, D)
            normalized MPS tensor with 3 legs,
            ordered left-bottom-right.
        l : np.array (D, D), optional
            left fixed point of transfermatrix,
            normalized.
        r : np.array (D, D), optional
            right fixed point of transfermatrix,
            normalized.
        
        Returns
        -------
        Rh : np.array (D, D)
            result of contraction,
            ordered top-bottom.
    """
    
    D = A.shape[0]
    
    # if l, r not specified, find fixed points
    if l is None or r is None:
        l, r = fixedPoints(A)
    
    # construct b, which is the matrix to the right of (1 - E)^P in the figure above
    #b = ncon((r, A, A, np.conj(A), np.conj(A), hTilde), ([4, 5], [-1, 2, 1], [1, 3, 4], [-2, 8, 7], [7, 6, 5], [2, 3, 8, 6]))
    b = ncon((l, np.conj(A), np.conj(A), A, A, A, A, np.conj(A), np.conj(A), r, r), 
            ([2, 1], [-1, 3, 5], [5, 9, 11], [-2, 4, 8], [8, 10, 14], 
             [1, 3, 6], [6, 9, 12], [2, 4, 7], [7, 10, 13], [12, 13], [14, 11]))
    
    # solve Ax = b for x
    A = LinearOperator((D ** 2, D ** 2), matvec=partial(EtildeRightInner, A, l, r))
    Rh = gmres(A, b.reshape(D ** 2))[0]
    
    return Rh.reshape((D, D))

# %%
d, D = 2, 4
A = createMPS(D, d)
A = normalizeMPS(A)

rhoA = uniformToRho(A)
l, r = fixedPoints(A)

# %%
# Verify RhAUniform reproduces previous Rh
Rh = RhUniform(rhoA, A)
RhA = RhAUniform(A)

# %%
np.allclose(Rh, RhA)
# Out:
# True

# %%
bInner = ncon((l, np.conj(A), np.conj(A), A, A, A, A, np.conj(A), np.conj(A), r, r), 
            ([2, 1], [-1, 3, 5], [5, 9, 11], [-2, 4, 8], [8, 10, 14], 
             [1, 3, 6], [6, 9, 12], [2, 4, 7], [7, 10, 13], [12, 13], [14, 11]))

# %%
bA = ncon((l, A, A, np.conj(A), np.conj(A), np.conj(A), np.conj(A), A, A, r, r), 
        ([1, 2], [-1, 3, 5], [5, 9, 11], [-2, 4, 8], [8, 10, 14], 
         [1, 3, 6], [6, 9, 12], [2, 4, 7], [7, 10, 13], [13, 12], [11, 14]))

# %%
RhARHS = EtildeRight(A, l, r, RhA).reshape(4, 4)

# %%
np.allclose(RhARHS, bA)
# Out:
# True

# %%
RhInnerRHS = EtildeRightInner(A, l, r, RhA.T).reshape(4, 4)

# %%
np.allclose(RhInnerRHS, bInner)
# Out:
# True

# %%
# Calculate RhAUniformInner and see if it is RhAUniform.T
RhAInner = RhAUniformInner(A)

# %%
np.allclose(RhA, RhAInner.T)
# Out:
# True

# %%
def gradLeftTerms(hTilde, A, l=None, r=None):
    """
    Calculate the value of the left terms.
    
        Parameters
        ----------
        hTilde : np.array (d, d, d, d)
            reduced Hamiltonian,
            ordered topLeft-topRight-bottomLeft-bottomRight,
            renormalized.
        A : np.array (D, d, D)
            MPS tensor with 3 legs,
            ordered left-bottom-right.
        l : np.array (D, D), optional
            left fixed point of transfermatrix,
            normalized.
        r : np.array (D, D), optional
            right fixed point of transfermatrix,
            normalized.
        
        Returns
        -------
        leftTerms : np.array (D, d, D)
            left terms of gradient,
            ordered left-mid-right.
    """
    
    # if l, r not specified, find fixed points
    if l is None or r is None:
        l, r = fixedPoints(A)
    
    # calculate partial contraction
    Rh = RhUniform(hTilde, A, l, r)
    
    # calculate full contraction
    leftTerms = ncon((Rh, A, l), ([1, -3], [2, -2, 1], [-1, 2]))
    
    return leftTerms

# %%
def gradLeftTermsA(A, l=None, r=None):
    """
    Calculate the value of the left terms.
    
        Parameters
        ----------
        A : np.array (D, d, D)
            MPS tensor with 3 legs,
            ordered left-bottom-right.
        l : np.array (D, D), optional
            left fixed point of transfermatrix,
            normalized.
        r : np.array (D, D), optional
            right fixed point of transfermatrix,
            normalized.
        
        Returns
        -------
        leftTerms : np.array (D, d, D)
            left terms of gradient,
            ordered left-mid-right.
    """
    
    # if l, r not specified, find fixed points
    if l is None or r is None:
        l, r = fixedPoints(A)
    
    # calculate partial contraction
    Rh = RhAUniform(A, l, r)
    
    # calculate full contraction
    leftTerms = ncon((Rh, A, l), ([1, -3], [2, -2, 1], [-1, 2]))
    
    return leftTerms

# %%
gradL = gradLeftTerms(rhoA, A)
gradAL = gradLeftTermsA(A)

# %%
np.allclose(gradL, gradAL)
# Out:
# True

# %%
def gradLeftTermsAInner(A, l=None, r=None):
    """
    Calculate the value of the left terms.
    
        Parameters
        ----------
        A : np.array (D, d, D)
            MPS tensor with 3 legs,
            ordered left-bottom-right.
        l : np.array (D, D), optional
            left fixed point of transfermatrix,
            normalized.
        r : np.array (D, D), optional
            right fixed point of transfermatrix,
            normalized.
        
        Returns
        -------
        leftTerms : np.array (D, d, D)
            left terms of gradient,
            ordered left-mid-right.
    """
    
    # if l, r not specified, find fixed points
    if l is None or r is None:
        l, r = fixedPoints(A)
    
    # calculate partial contraction
    Rh = RhAUniformInner(A, l, r)
    
    # calculate full contraction
    leftTerms = ncon((Rh, A, l), ([-3, 1], [2, -2, 1], [-1, 2]))
    
    return leftTerms

# %%
gradALInner = gradLeftTermsAInner(A)

# %%
np.allclose(gradALInner, gradAL)
# Out:
# True
