# %%
# %load_ext autoreload
# %autoreload 2

# %%
# do all necessary imports for this chapter
import matplotlib.pyplot as plt
import numpy as np
from ncon import ncon
from scipy.optimize import minimize
from scipy.sparse.linalg import eigs, LinearOperator, gmres
from scipy.linalg import svd, polar, null_space
from functools import partial
from time import time
from tutorialFunctions import createMPS, normalizeMPS, fixedPoints, rightOrthonormalize, mixedCanonical, expVal2Uniform, expVal2Mixed
from densityFunctions import traceDistance

# %%
def uniformToRho(A):
    l, r = fixedPoints(A)
    rho = ncon([l, A, A, A.conj(), A.conj(), r],
                 ((2, 1), (1, -3, 4), (4, -4, 6), (2, -1, 7), (7, -2, 8), (6, 8)))
    return rho

# %%
def gradCenterTerms(hTilde, A, l=None, r=None):
    """
    Calculate the value of the center terms.
    
        Parameters
        ----------
        hTilde : np.array (d, d, d, d)
            reduced Hamiltonian,
            ordered topLeft-topRight-bottomLeft-bottomRight.
        A : np.array (D, d, D)
            normalized MPS tensor with 3 legs,
            ordered left-bottom-right.
        l : np.array (D, D), optional
            left fixed point of transfermatrix,
            normalized.
        r : np.array (D, D), optional
            right fixed point of transfermatrix,
            normalized.
        
        Returns
        -------
        term1 : np.array (D, d, D)
            first term of gradient,
            ordered left-mid-right.
        term2 : np.array (D, d, D)
            second term of gradient,
            ordered left-mid-right.
    """
    
    # calculate fixed points if not supplied
    if l is None or r is None:
        l, r = fixedPoints(A)
        
    # calculate first contraction
    term1 = ncon((l, r, A, A, np.conj(A), hTilde), ([-1, 1], [5, 7], [1, 3, 2], [2, 4, 5], [-3, 6, 7], [3, 4, -2, 6]))
    
    # calculate second contraction
    term2 = ncon((l, r, A, A, np.conj(A), hTilde), ([6, 1], [5, -3], [1, 3, 2], [2, 4, 5], [6, 7, -1], [3, 4, 7, -2]))

    
    return term1, term2

# %%
def gradCenterTermsAA(A, l=None, r=None):
    if l is None or r is None:
        l, r = fixedPoints(A)
    
    # # Contraction to calculate TrAA
    # tensors = [l, A, A, A.conj(), A.conj(), r, l, A, A, A.conj(), A.conj(), r]
    # edges = [
    #     (1, 2), (2, 6, 10), (10, 12, 14), (1, 5, 7), (7, 11, 13), (14, 13),
    #     (4, 3), (3, 5, 8), (8, 11, 15), (4, 6, 9), (9, 12, 16), (15, 16)
    # ]
    
    tensors = [l, A, A, A.conj(), r, l, A, A, A.conj(), A.conj(), r]
    edges = [
        (-1, 2), (2, 6, 10), (10, 12, 14), (-3, 11, 13), (14, 13),
        (4, 3), (3, -2, 8), (8, 11, 15), (4, 6, 9), (9, 12, 16), (15, 16)
    ]
    term1 = ncon(tensors, edges)
    
    tensors = [l, A, A, A.conj(), r, l, A, A, A.conj(), A.conj(), r]
    edges = [
        (1, 2), (2, 6, 10), (10, 12, 14), (1, 5, -1), (14, -3),
        (4, 3), (3, 5, 8), (8, -2, 15), (4, 6, 9), (9, 12, 16), (15, 16)
    ]
    term2 = ncon(tensors, edges)
    
    tensors = [l, A, A, A.conj(), A.conj(), r, l, A, A, A.conj(), r]
    edges = [
        (1, 2), (2, -2, 10), (10, 12, 14), (1, 5, 7), (7, 11, 13), (14, 13),
        (-1, 3), (3, 5, 8), (8, 11, 15), (-3, 12, 16), (15, 16)
    ]
    term3 = ncon(tensors, edges)
    
    tensors = [l, A, A, A.conj(), A.conj(), r, l, A, A, A.conj(), r]
    edges = [
        (1, 2), (2, 6, 10), (10, -2, 14), (1, 5, 7), (7, 11, 13), (14, 13),
        (4, 3), (3, 5, 8), (8, 11, 15), (4, 6, -1), (15, -3)
    ]
    term4 = ncon(tensors, edges)
    
    return term1, term2, term3, term4

# %%
def reducedHamUniform(h, A, l=None, r=None):
    """
    Regularize Hamiltonian such that its expectation value is 0.
    
        Parameters
        ----------
        h : np.array (d, d, d, d)
            Hamiltonian that needs to be reduced,
            ordered topLeft-topRight-bottomLeft-bottomRight.
        A : np.array (D, d, D)
            normalized MPS tensor with 3 legs,
            ordered left-bottom-right.
        l : np.array (D, D), optional
            left fixed point of transfermatrix,
            normalized.
        r : np.array (D, D), optional
            right fixed point of transfermatrix,
            normalized.
            
        Returns
        -------
        hTilde : np.array (d, d, d, d)
            reduced Hamiltonian,
            ordered topLeft-topRight-bottomLeft-bottomRight.
    """
    
    d = A.shape[1]
    
    # calculate fixed points if not supplied
    if l is None or r is None:
        l, r = fixedPoints(A)
    
    # calculate expectation value
    e = np.real(expVal2Uniform(h, A, l, r))
    
    # substract from hamiltonian
    hTilde = h - e * ncon((np.eye(d), np.eye(d)), ([-1, -3], [-2, -4]))
    
    return hTilde

# %%
def EtildeRight(A, l, r, v):
    """
    Implement the action of (1 - Etilde) on a right vector v.
    
        Parameters
        ----------
        A : np.array (D, d, D)
            normalized MPS tensor with 3 legs,
            ordered left-bottom-right.
        l : np.array (D, D), optional
            left fixed point of transfermatrix,
            normalized.
        r : np.array (D, D), optional
            right fixed point of transfermatrix,
            normalized.
        v : np.array (D**2)
            right matrix of size (D, D) on which
            (1 - Etilde) acts,
            given as a vector of size (D**2,)
        
        Returns
        -------
        vNew : np.array (D**2)
            result of action of (1 - Etilde)
            on a right matrix,
            given as a vector of size (D**2,)
    """
    
    D = A.shape[0]
    
    # reshape to matrix
    v = v.reshape(D, D)
        
    # transfermatrix contribution
    transfer = ncon((A, np.conj(A), v), ([-1, 2, 1], [-2, 2, 3], [1, 3]))

    # fixed point contribution
    fixed = np.trace(l @ v) * r

    # sum these with the contribution of the identity
    vNew = v - transfer + fixed

    return vNew.reshape((D ** 2))

# %%
def RhUniform(hTilde, A, l=None, r=None):
    """
    Find the partial contraction for Rh.
    
        Parameters
        ----------
        hTilde : np.array (d, d, d, d)
            reduced Hamiltonian,
            ordered topLeft-topRight-bottomLeft-bottomRight,
            renormalized.
        A : np.array (D, d, D)
            normalized MPS tensor with 3 legs,
            ordered left-bottom-right.
        l : np.array (D, D), optional
            left fixed point of transfermatrix,
            normalized.
        r : np.array (D, D), optional
            right fixed point of transfermatrix,
            normalized.
        
        Returns
        -------
        Rh : np.array (D, D)
            result of contraction,
            ordered top-bottom.
    """
    
    D = A.shape[0]
    
    # if l, r not specified, find fixed points
    if l is None or r is None:
        l, r = fixedPoints(A)
    
    # construct b, which is the matrix to the right of (1 - E)^P in the figure above
    b = ncon((r, A, A, np.conj(A), np.conj(A), hTilde), ([4, 5], [-1, 2, 1], [1, 3, 4], [-2, 8, 7], [7, 6, 5], [2, 3, 8, 6]))
    
    # solve Ax = b for x
    A = LinearOperator((D ** 2, D ** 2), matvec=partial(EtildeRight, A, l, r))
    Rh = gmres(A, b.reshape(D ** 2))[0]
    
    return Rh.reshape((D, D))

# %%
def gradLeftTerms(hTilde, A, l=None, r=None):
    """
    Calculate the value of the left terms.
    
        Parameters
        ----------
        hTilde : np.array (d, d, d, d)
            reduced Hamiltonian,
            ordered topLeft-topRight-bottomLeft-bottomRight,
            renormalized.
        A : np.array (D, d, D)
            MPS tensor with 3 legs,
            ordered left-bottom-right.
        l : np.array (D, D), optional
            left fixed point of transfermatrix,
            normalized.
        r : np.array (D, D), optional
            right fixed point of transfermatrix,
            normalized.
        
        Returns
        -------
        leftTerms : np.array (D, d, D)
            left terms of gradient,
            ordered left-mid-right.
    """
    
    # if l, r not specified, find fixed points
    if l is None or r is None:
        l, r = fixedPoints(A)
    
    # calculate partial contraction
    Rh = RhUniform(hTilde, A, l, r)
    
    # calculate full contraction
    leftTerms = ncon((Rh, A, l), ([1, -3], [2, -2, 1], [-1, 2]))
    
    return leftTerms

# %%
def EtildeLeft(A, l, r, v):
    """
    Implement the action of (1 - Etilde) on a left vector v.
    
        Parameters
        ----------
        A : np.array (D, d, D)
            normalized MPS tensor with 3 legs,
            ordered left-bottom-right.
        l : np.array (D, D), optional
            left fixed point of transfermatrix,
            normalized.
        r : np.array (D, D), optional
            right fixed point of transfermatrix,
            normalized.
        v : np.array (D**2)
            left matrix of size (D, D) on which
            (1 - Etilde) acts,
            given as a vector of size (D**2,)
        
        Returns
        -------
        vNew : np.array (D**2)
            result of action of (1 - Etilde)
            on a left matrix,
            given as a vector of size (D**2,)
    """
    
    D = A.shape[0]
    
    # reshape to matrix
    v = v.reshape(D, D)

    # transfer matrix contribution
    transfer = ncon((v, A, np.conj(A)), ([3, 1], [1, 2, -2], [3, 2, -1]))

    # fixed point contribution
    fixed = np.trace(v @ r) * l

    # sum these with the contribution of the identity
    vNew = v - transfer + fixed

    return vNew.reshape((D ** 2))

# %%
def LhUniform(hTilde, A, l=None, r=None):
    """
    Find the partial contraction for Lh.
    
        Parameters
        ----------
        hTilde : np.array (d, d, d, d)
            reduced Hamiltonian,
            ordered topLeft-topRight-bottomLeft-bottomRight,
            renormalized.
        A : np.array (D, d, D)
            MPS tensor with 3 legs,
            ordered left-bottom-right.
        l : np.array (D, D), optional
            left fixed point of transfermatrix,
            normalized.
        r : np.array (D, D), optional
            right fixed point of transfermatrix,
            normalized.
        
        Returns
        -------
        Lh : np.array (D, D)
            result of contraction,
            ordered bottom-top.
    """
    
    D = A.shape[0]
    
    # if l, r not specified, find fixed points
    if l is None or r is None:
        l, r = fixedPoints(A)
    
    # construct b, which is the matrix to the right of (1 - E)^P in the figure above
    b = ncon((l, A, A, np.conj(A), np.conj(A), hTilde), ([5, 1], [1, 3, 2], [2, 4, -2], [5, 6, 7], [7, 8, -1], [3, 4, 6, 8]))    
    
    # solve Ax = b for x
    A = LinearOperator((D ** 2, D ** 2), matvec=partial(EtildeLeft, A, l, r)) 
    Lh = gmres(A, b.reshape(D ** 2))[0]
    
    return Lh.reshape((D, D))

# %%
def gradRightTerms(hTilde, A, l=None, r=None):
    """
    Calculate the value of the right terms.
    
        Parameters
        ----------
        hTilde : np.array (d, d, d, d)
            reduced Hamiltonian,
            ordered topLeft-topRight-bottomLeft-bottomRight,
            renormalized.
        A : np.array (D, d, D)
            MPS tensor with 3 legs,
            ordered left-bottom-right.
        l : np.array (D, D), optional
            left fixed point of transfermatrix,
            normalized.
        r : np.array (D, D), optional
            right fixed point of transfermatrix,
            normalized.
        
        Returns
        -------
        rightTerms : np.array (D, d, D)
            right terms of gradient,
            ordered left-mid-right.
    """
    
    # if l, r not specified, find fixed points
    if l is None or r is None:
        l, r = fixedPoints(A)
    
    # calculate partial contraction
    Lh = LhUniform(hTilde, A, l, r)
    
    # calculate full contraction
    rightTerms = ncon((Lh, A, r), ([-1, 1], [1, -2, 2], [2, -3]))
    
    return rightTerms

# %%
def gradient(h, A, l=None, r=None):
    """
    Calculate the gradient of the expectation value of h @ MPS A.
    
        Parameters
        ----------
        h : np.array (d, d, d, d)
            Hamiltonian,
            ordered topLeft-topRight-bottomLeft-bottomRight,
            renormalized.
        A : np.array (D, d, D)
            MPS tensor with 3 legs,
            ordered left-bottom-right.
        l : np.array (D, D), optional
            left fixed point of transfermatrix,
            normalized.
        r : np.array (D, D), optional
            right fixed point of transfermatrix,
            normalized.
        
        Returns
        -------
        grad : np.array (D, d, D)
            Gradient,
            ordered left-mid-right.
    """
    
    # if l, r not specified, find fixed points
    if l is None or r is None:
        l, r = fixedPoints(A)
        
    # renormalize Hamiltonian and A
    # hTilde = reducedHamUniform(h, A, l, r)
    # hTildeA = reducedHamUniform(rhoA, A, l, r)
    hTilde = h
        
    # find terms
    centerTerm1, centerTerm2 = gradCenterTerms(hTilde, A, l, r)
    leftTerms = gradLeftTerms(hTilde, A, l, r)
    rightTerms = gradRightTerms(hTilde, A, l, r)
    
    centerTermAA1, centerTermAA2, centerTermAA3, centerTermAA4 = gradCenterTermsAA(A, l, r)
    # leftTermsA = gradLeftTerms(hTildeA, A, l, r)
    # rightTermsA = gradRightTerms(hTildeA, A, l, r)
    
    # grad = (centerTerm1A + centerTerm2A + leftTermsA + rightTermsA)

    grad = centerTermAA1 + centerTermAA2 + centerTermAA3 + centerTermAA4 # + leftTermsA + rightTermsA
    grad -= 2 * (centerTerm1 + centerTerm2)
    # grad -= 2 * (centerTerm1 + centerTerm2 + leftTerms + rightTerms)
    
#     AAterms = centerTermAA1 + centerTermAA2 + centerTermAA3 + centerTermAA4
#     ABterms = centerTerm1 + centerTerm2# + leftTerms + rightTerms
#     print('AA Terms')
#     print(AAterms)
#     print()
#     print('AB Terms')
#     print(ABterms)
#     print()
#     print('AA Terms - AB Terms')
#     print(AAterms - 2*ABterms)
    
    return grad

# %%
def optimiseDensityGradDescent(h, D, eps=1e-1, A0=None, tol=1e-4, maxIter=1e4, verbose=True):
    """
    Find the ground state using gradient descent.
    
        Parameters
        ----------
        h : np.array (d, d, d, d)
            Hamiltonian to minimize,
            ordered topLeft-topRight-bottomLeft-bottomRight.
        D : int
            Bond dimension
        eps : float
            Stepsize.
        A0 : np.array (D, d, D)
            normalized MPS tensor with 3 legs,
            ordered left-bottom-right,
            initial guess.
        tol : float
            Tolerance for convergence criterium.
        
        Returns
        -------
        E : float
            expectation value @ minimum
        A : np.array (D, d, D)
            ground state MPS,
            ordered left-mid-right.
    """
    
    d = h.shape[0]
    
    # if no initial value, choose random
    if A0 is None:
        A0 = createMPS(D, d)
        A0 = normalizeMPS(A0)
    
    # calculate gradient
    g = gradient(h, A0)
    
    A = A0
    
    i = 0
    
    while not(np.linalg.norm(g) < tol):
        # do a step
        A = A - eps * g
        A = normalizeMPS(A)
        i += 1
        
        if verbose and not(i % 50):
            #E = np.real(expVal2Uniform(h, A))
            rhoA = uniformToRho(A)
            E = traceDistance(h, rhoA)
            print('iteration:\t{:d}\tdist:\t{:.12f}\tgradient norm:\t{:.4e}'.format(i, E, np.linalg.norm(g)))
        
        # calculate new gradient
        g = gradient(h, A)
        
        if i > maxIter:
            print('Warning: gradient descent did not converge!')
            break
    
    # calculate ground state energy
    # E = np.real(expVal2Uniform(h, A))
    rhoA = uniformToRho(A)
    E = traceDistance(h, rhoA)   
    
    return E, A

# %%
# Prepare state to optimise
d0, D0 = 2, 2
A0 = createMPS(D0, d0)
A0 = normalizeMPS(A0)

h = uniformToRho(A0)

# %%
d, D = 2, 2
A = createMPS(D, d)
A = normalizeMPS(A)
#A = A0

print('Gradient descent optimization:\n')
t0 = time()
E1, A1 = optimiseDensityGradDescent(h, D, eps=1e-1, A0=A, tol=1e-5, maxIter=1e4)
print('Time until convergence:', time()-t0, 's')
print('Computed trace dist:', E1, '\n')
# Out:
# Gradient descent optimization:
#
# iteration:	50	dist:	0.001048146692	gradient norm:	1.1390e-02
# iteration:	100	dist:	0.000342371248	gradient norm:	6.2596e-03
# iteration:	150	dist:	0.000116072965	gradient norm:	3.7290e-03
# iteration:	200	dist:	0.000038146066	gradient norm:	2.1904e-03
# iteration:	250	dist:	0.000012112605	gradient norm:	1.2484e-03
# iteration:	300	dist:	0.000003763249	gradient norm:	6.9312e-04
# iteration:	350	dist:	0.000001161055	gradient norm:	3.7822e-04
# iteration:	400	dist:	0.000000361425	gradient norm:	2.0703e-04
# iteration:	450	dist:	0.000000116017	gradient norm:	1.2149e-04
# iteration:	500	dist:	0.000000039856	gradient norm:	8.7049e-05
# iteration:	550	dist:	0.000000015611	gradient norm:	7.8177e-05
# iteration:	600	dist:	0.000000007553	gradient norm:	7.7720e-05
# iteration:	650	dist:	0.000000004700	gradient norm:	7.8825e-05
# iteration:	700	dist:	0.000000003604	gradient norm:	7.9786e-05
# iteration:	750	dist:	0.000000003143	gradient norm:	8.0382e-05
# iteration:	800	dist:	0.000000002933	gradient norm:	8.0698e-05
# iteration:	850	dist:	0.000000002830	gradient norm:	8.0837e-05
# iteration:	900	dist:	0.000000002776	gradient norm:	8.0874e-05
# iteration:	950	dist:	0.000000002746	gradient norm:	8.0852e-05
# iteration:	1000	dist:	0.000000002729	gradient norm:	8.0798e-05
# iteration:	1050	dist:	0.000000002718	gradient norm:	8.0726e-05
# iteration:	1100	dist:	0.000000002710	gradient norm:	8.0644e-05
# iteration:	1150	dist:	0.000000002705	gradient norm:	8.0557e-05
# iteration:	1200	dist:	0.000000002700	gradient norm:	8.0468e-05
# iteration:	1250	dist:	0.000000002696	gradient norm:	8.0377e-05
# iteration:	1300	dist:	0.000000002692	gradient norm:	8.0286e-05
# iteration:	1350	dist:	0.000000002689	gradient norm:	8.0194e-05
# iteration:	1400	dist:	0.000000002685	gradient norm:	8.0102e-05
# iteration:	1450	dist:	0.000000002681	gradient norm:	8.0010e-05
# iteration:	1500	dist:	0.000000002678	gradient norm:	7.9919e-05
# iteration:	1550	dist:	0.000000002675	gradient norm:	7.9828e-05
# iteration:	1600	dist:	0.000000002671	gradient norm:	7.9736e-05
# iteration:	1650	dist:	0.000000002668	gradient norm:	7.9645e-05
# iteration:	1700	dist:	0.000000002664	gradient norm:	7.9555e-05
# iteration:	1750	dist:	0.000000002661	gradient norm:	7.9464e-05
# iteration:	1800	dist:	0.000000002657	gradient norm:	7.9374e-05
# iteration:	1850	dist:	0.000000002654	gradient norm:	7.9284e-05
# iteration:	1900	dist:	0.000000002651	gradient norm:	7.9194e-05
# iteration:	1950	dist:	0.000000002647	gradient norm:	7.9105e-05
# iteration:	2000	dist:	0.000000002644	gradient norm:	7.9015e-05
# iteration:	2050	dist:	0.000000002641	gradient norm:	7.8926e-05
# iteration:	2100	dist:	0.000000002637	gradient norm:	7.8837e-05
# iteration:	2150	dist:	0.000000002634	gradient norm:	7.8749e-05
# iteration:	2200	dist:	0.000000002631	gradient norm:	7.8660e-05
# iteration:	2250	dist:	0.000000002627	gradient norm:	7.8572e-05
# iteration:	2300	dist:	0.000000002624	gradient norm:	7.8484e-05
# iteration:	2350	dist:	0.000000002621	gradient norm:	7.8396e-05
# iteration:	2400	dist:	0.000000002618	gradient norm:	7.8308e-05
# iteration:	2450	dist:	0.000000002614	gradient norm:	7.8221e-05
# iteration:	2500	dist:	0.000000002611	gradient norm:	7.8134e-05
# iteration:	2550	dist:	0.000000002608	gradient norm:	7.8047e-05
# iteration:	2600	dist:	0.000000002605	gradient norm:	7.7960e-05
# iteration:	2650	dist:	0.000000002601	gradient norm:	7.7874e-05
# iteration:	2700	dist:	0.000000002598	gradient norm:	7.7787e-05
# iteration:	2750	dist:	0.000000002595	gradient norm:	7.7701e-05
# iteration:	2800	dist:	0.000000002592	gradient norm:	7.7615e-05
# iteration:	2850	dist:	0.000000002589	gradient norm:	7.7530e-05
# iteration:	2900	dist:	0.000000002585	gradient norm:	7.7444e-05
# iteration:	2950	dist:	0.000000002582	gradient norm:	7.7359e-05
# iteration:	3000	dist:	0.000000002579	gradient norm:	7.7274e-05
# iteration:	3050	dist:	0.000000002576	gradient norm:	7.7189e-05
# iteration:	3100	dist:	0.000000002573	gradient norm:	7.7105e-05
# iteration:	3150	dist:	0.000000002570	gradient norm:	7.7020e-05
# iteration:	3200	dist:	0.000000002566	gradient norm:	7.6936e-05
# iteration:	3250	dist:	0.000000002563	gradient norm:	7.6852e-05
# iteration:	3300	dist:	0.000000002560	gradient norm:	7.6768e-05
# iteration:	3350	dist:	0.000000002557	gradient norm:	7.6685e-05
# iteration:	3400	dist:	0.000000002554	gradient norm:	7.6601e-05
# iteration:	3450	dist:	0.000000002551	gradient norm:	7.6518e-05
# iteration:	3500	dist:	0.000000002548	gradient norm:	7.6435e-05
# iteration:	3550	dist:	0.000000002545	gradient norm:	7.6352e-05
# iteration:	3600	dist:	0.000000002542	gradient norm:	7.6269e-05
# iteration:	3650	dist:	0.000000002539	gradient norm:	7.6187e-05
# iteration:	3700	dist:	0.000000002536	gradient norm:	7.6105e-05
# iteration:	3750	dist:	0.000000002533	gradient norm:	7.6023e-05
# iteration:	3800	dist:	0.000000002530	gradient norm:	7.5941e-05
# iteration:	3850	dist:	0.000000002527	gradient norm:	7.5859e-05
# iteration:	3900	dist:	0.000000002524	gradient norm:	7.5778e-05
# iteration:	3950	dist:	0.000000002521	gradient norm:	7.5697e-05
# iteration:	4000	dist:	0.000000002518	gradient norm:	7.5616e-05
# iteration:	4050	dist:	0.000000002515	gradient norm:	7.5535e-05
# iteration:	4100	dist:	0.000000002512	gradient norm:	7.5454e-05
# iteration:	4150	dist:	0.000000002509	gradient norm:	7.5373e-05
# iteration:	4200	dist:	0.000000002506	gradient norm:	7.5293e-05
# iteration:	4250	dist:	0.000000002503	gradient norm:	7.5213e-05
# iteration:	4300	dist:	0.000000002500	gradient norm:	7.5133e-05
# iteration:	4350	dist:	0.000000002497	gradient norm:	7.5053e-05
# iteration:	4400	dist:	0.000000002494	gradient norm:	7.4974e-05
# iteration:	4450	dist:	0.000000002491	gradient norm:	7.4894e-05
# iteration:	4500	dist:	0.000000002488	gradient norm:	7.4815e-05
# iteration:	4550	dist:	0.000000002486	gradient norm:	7.4736e-05
# iteration:	4600	dist:	0.000000002483	gradient norm:	7.4657e-05
# iteration:	4650	dist:	0.000000002480	gradient norm:	7.4579e-05
# iteration:	4700	dist:	0.000000002477	gradient norm:	7.4500e-05
# iteration:	4750	dist:	0.000000002474	gradient norm:	7.4422e-05
# iteration:	4800	dist:	0.000000002471	gradient norm:	7.4344e-05
# iteration:	4850	dist:	0.000000002468	gradient norm:	7.4266e-05
# iteration:	4900	dist:	0.000000002466	gradient norm:	7.4188e-05
# iteration:	4950	dist:	0.000000002463	gradient norm:	7.4111e-05
# iteration:	5000	dist:	0.000000002460	gradient norm:	7.4033e-05
# iteration:	5050	dist:	0.000000002457	gradient norm:	7.3956e-05
# iteration:	5100	dist:	0.000000002454	gradient norm:	7.3879e-05
# iteration:	5150	dist:	0.000000002452	gradient norm:	7.3802e-05
# iteration:	5200	dist:	0.000000002449	gradient norm:	7.3725e-05
# iteration:	5250	dist:	0.000000002446	gradient norm:	7.3649e-05
# iteration:	5300	dist:	0.000000002443	gradient norm:	7.3573e-05
# iteration:	5350	dist:	0.000000002440	gradient norm:	7.3496e-05
# iteration:	5400	dist:	0.000000002438	gradient norm:	7.3420e-05
# iteration:	5450	dist:	0.000000002435	gradient norm:	7.3345e-05
# iteration:	5500	dist:	0.000000002432	gradient norm:	7.3269e-05
# iteration:	5550	dist:	0.000000002429	gradient norm:	7.3193e-05
# iteration:	5600	dist:	0.000000002427	gradient norm:	7.3118e-05
# iteration:	5650	dist:	0.000000002424	gradient norm:	7.3043e-05
# iteration:	5700	dist:	0.000000002421	gradient norm:	7.2968e-05
# iteration:	5750	dist:	0.000000002419	gradient norm:	7.2893e-05
# iteration:	5800	dist:	0.000000002416	gradient norm:	7.2819e-05
# iteration:	5850	dist:	0.000000002413	gradient norm:	7.2744e-05
# iteration:	5900	dist:	0.000000002411	gradient norm:	7.2670e-05
# iteration:	5950	dist:	0.000000002408	gradient norm:	7.2596e-05
# iteration:	6000	dist:	0.000000002405	gradient norm:	7.2522e-05
# iteration:	6050	dist:	0.000000002403	gradient norm:	7.2448e-05
# iteration:	6100	dist:	0.000000002400	gradient norm:	7.2374e-05
# iteration:	6150	dist:	0.000000002397	gradient norm:	7.2301e-05
# iteration:	6200	dist:	0.000000002395	gradient norm:	7.2227e-05
# iteration:	6250	dist:	0.000000002392	gradient norm:	7.2154e-05
# iteration:	6300	dist:	0.000000002389	gradient norm:	7.2081e-05
# iteration:	6350	dist:	0.000000002387	gradient norm:	7.2008e-05
# iteration:	6400	dist:	0.000000002384	gradient norm:	7.1935e-05
# iteration:	6450	dist:	0.000000002381	gradient norm:	7.1863e-05
# iteration:	6500	dist:	0.000000002379	gradient norm:	7.1791e-05
# iteration:	6550	dist:	0.000000002376	gradient norm:	7.1718e-05
# iteration:	6600	dist:	0.000000002374	gradient norm:	7.1646e-05
# iteration:	6650	dist:	0.000000002371	gradient norm:	7.1574e-05
# iteration:	6700	dist:	0.000000002369	gradient norm:	7.1503e-05
# iteration:	6750	dist:	0.000000002366	gradient norm:	7.1431e-05
# iteration:	6800	dist:	0.000000002363	gradient norm:	7.1360e-05
# iteration:	6850	dist:	0.000000002361	gradient norm:	7.1288e-05
# iteration:	6900	dist:	0.000000002358	gradient norm:	7.1217e-05
# iteration:	6950	dist:	0.000000002356	gradient norm:	7.1146e-05
# iteration:	7000	dist:	0.000000002353	gradient norm:	7.1075e-05
# iteration:	7050	dist:	0.000000002351	gradient norm:	7.1005e-05
# iteration:	7100	dist:	0.000000002348	gradient norm:	7.0934e-05
# iteration:	7150	dist:	0.000000002346	gradient norm:	7.0864e-05
# iteration:	7200	dist:	0.000000002343	gradient norm:	7.0794e-05
# iteration:	7250	dist:	0.000000002341	gradient norm:	7.0723e-05
# iteration:	7300	dist:	0.000000002338	gradient norm:	7.0654e-05
# iteration:	7350	dist:	0.000000002336	gradient norm:	7.0584e-05
# iteration:	7400	dist:	0.000000002333	gradient norm:	7.0514e-05
# iteration:	7450	dist:	0.000000002331	gradient norm:	7.0445e-05
# iteration:	7500	dist:	0.000000002328	gradient norm:	7.0375e-05
# iteration:	7550	dist:	0.000000002326	gradient norm:	7.0306e-05
# iteration:	7600	dist:	0.000000002323	gradient norm:	7.0237e-05
# iteration:	7650	dist:	0.000000002321	gradient norm:	7.0168e-05
# iteration:	7700	dist:	0.000000002318	gradient norm:	7.0100e-05
# iteration:	7750	dist:	0.000000002316	gradient norm:	7.0031e-05
# iteration:	7800	dist:	0.000000002314	gradient norm:	6.9962e-05
# iteration:	7850	dist:	0.000000002311	gradient norm:	6.9894e-05
# iteration:	7900	dist:	0.000000002309	gradient norm:	6.9826e-05
# iteration:	7950	dist:	0.000000002306	gradient norm:	6.9758e-05
# iteration:	8000	dist:	0.000000002304	gradient norm:	6.9690e-05
# iteration:	8050	dist:	0.000000002302	gradient norm:	6.9622e-05
# iteration:	8100	dist:	0.000000002299	gradient norm:	6.9555e-05
# iteration:	8150	dist:	0.000000002297	gradient norm:	6.9487e-05
# iteration:	8200	dist:	0.000000002294	gradient norm:	6.9420e-05
# iteration:	8250	dist:	0.000000002292	gradient norm:	6.9353e-05
# iteration:	8300	dist:	0.000000002290	gradient norm:	6.9286e-05
# iteration:	8350	dist:	0.000000002287	gradient norm:	6.9219e-05
# iteration:	8400	dist:	0.000000002285	gradient norm:	6.9152e-05
# iteration:	8450	dist:	0.000000002283	gradient norm:	6.9085e-05
# iteration:	8500	dist:	0.000000002280	gradient norm:	6.9019e-05
# iteration:	8550	dist:	0.000000002278	gradient norm:	6.8953e-05
# iteration:	8600	dist:	0.000000002275	gradient norm:	6.8886e-05
# iteration:	8650	dist:	0.000000002273	gradient norm:	6.8820e-05
# iteration:	8700	dist:	0.000000002271	gradient norm:	6.8754e-05
# iteration:	8750	dist:	0.000000002269	gradient norm:	6.8689e-05
# iteration:	8800	dist:	0.000000002266	gradient norm:	6.8623e-05
# iteration:	8850	dist:	0.000000002264	gradient norm:	6.8557e-05
# iteration:	8900	dist:	0.000000002262	gradient norm:	6.8492e-05
# iteration:	8950	dist:	0.000000002259	gradient norm:	6.8427e-05
# iteration:	9000	dist:	0.000000002257	gradient norm:	6.8361e-05
# iteration:	9050	dist:	0.000000002255	gradient norm:	6.8296e-05
# iteration:	9100	dist:	0.000000002252	gradient norm:	6.8232e-05
# iteration:	9150	dist:	0.000000002250	gradient norm:	6.8167e-05
# iteration:	9200	dist:	0.000000002248	gradient norm:	6.8102e-05
# iteration:	9250	dist:	0.000000002246	gradient norm:	6.8038e-05
# iteration:	9300	dist:	0.000000002243	gradient norm:	6.7973e-05
# iteration:	9350	dist:	0.000000002241	gradient norm:	6.7909e-05
# iteration:	9400	dist:	0.000000002239	gradient norm:	6.7845e-05
# iteration:	9450	dist:	0.000000002237	gradient norm:	6.7781e-05
# iteration:	9500	dist:	0.000000002234	gradient norm:	6.7717e-05
# iteration:	9550	dist:	0.000000002232	gradient norm:	6.7654e-05
# iteration:	9600	dist:	0.000000002230	gradient norm:	6.7590e-05
# iteration:	9650	dist:	0.000000002228	gradient norm:	6.7527e-05
# iteration:	9700	dist:	0.000000002225	gradient norm:	6.7463e-05
# iteration:	9750	dist:	0.000000002223	gradient norm:	6.7400e-05
# iteration:	9800	dist:	0.000000002221	gradient norm:	6.7337e-05
# iteration:	9850	dist:	0.000000002219	gradient norm:	6.7274e-05
# iteration:	9900	dist:	0.000000002217	gradient norm:	6.7211e-05
# iteration:	9950	dist:	0.000000002214	gradient norm:	6.7148e-05
# iteration:	10000	dist:	0.000000002212	gradient norm:	6.7086e-05
# Warning: gradient descent did not converge!
# Time until convergence: 66.57081651687622 s
# Computed trace dist: 2.212228003436226e-09

# %% [markdown]
# ---
# ## Testing $Tr(\rho_A \rho_B)$
#
# Want to make sure that the construction using tensor networks is the same as the construction using standard matrices.

# %%
d, D = 2, 4
A = createMPS(D, d)
A = normalizeMPS(A)

B = createMPS(D, d)
B = normalizeMPS(B)

rhoA = uniformToRho(A).reshape(d**2, d**2)
rhoB = uniformToRho(B).reshape(d**2, d**2)

TrAB = np.trace(rhoA @ rhoB)

# %%
TrAB

# %%
def tensorTrAB(A, B):
    
    lA, rA = fixedPoints(A)
    lB, rB = fixedPoints(B)
    tensors = [lB, B, B, B.conj(), B.conj(), rB, lA, A, A, A.conj(), A.conj(), rA]
    edges = [
        (1, 2), (2, 6, 10), (10, 12, 14), (1, 5, 7), (7, 11, 13), (14, 13),
        (4, 3), (3, 5, 8), (8, 11, 15), (4, 6, 9), (9, 12, 16), (15, 16)
    ]
    
    return ncon(tensors, edges)

# %%
TrAB_tensor = tensorTrAB(A, B)

# %%
TrAB_tensor

# %%
print(np.allclose(TrAB, TrAB_tensor))

# %%
traceDistExact = traceDistance(rhoA.reshape(d, d, d, d), rhoB.reshape(d, d, d, d))
traceDistExact

# %%
traceDist_Tensor = tensorTrAB(A, A) + tensorTrAB(B, B) - 2*tensorTrAB(A, B)
traceDist_Tensor

# %%
np.allclose(traceDistExact, traceDist_Tensor)

# %% [markdown]
# ## Verify gradient is `0` when `A == B`

# %%
d, D = 2, 4
A = createMPS(D, d)
A = normalizeMPS(A)

rhoA = uniformToRho(A)

# %%
gradient(rhoA, A)

# %%
np.linalg.norm(_)
