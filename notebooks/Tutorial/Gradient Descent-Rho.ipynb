# %%
# %load_ext autoreload
# %autoreload 2

# %%
# do all necessary imports for this chapter
import matplotlib.pyplot as plt
import numpy as np
from ncon import ncon
from scipy.optimize import minimize
from scipy.sparse.linalg import eigs, LinearOperator, gmres
from scipy.linalg import svd, polar, null_space
from functools import partial
from time import time
from tutorialFunctions import createMPS, normalizeMPS, fixedPoints, rightOrthonormalize, mixedCanonical, expVal2Uniform, expVal2Mixed
from densityFunctions import traceDistance

# %%
def uniformToRho(A):
    l, r = fixedPoints(A)
    rho = ncon([l, A, A, A.conj(), A.conj(), r],
                 ((2, 1), (1, -1, 4), (4, -2, 6), (2, -3, 7), (7, -4, 8), (6, 8)))
    return rho

# %%
def gradCenterTerms(hTilde, A, l=None, r=None):
    """
    Calculate the value of the center terms.
    
        Parameters
        ----------
        hTilde : np.array (d, d, d, d)
            reduced Hamiltonian,
            ordered topLeft-topRight-bottomLeft-bottomRight.
        A : np.array (D, d, D)
            normalized MPS tensor with 3 legs,
            ordered left-bottom-right.
        l : np.array (D, D), optional
            left fixed point of transfermatrix,
            normalized.
        r : np.array (D, D), optional
            right fixed point of transfermatrix,
            normalized.
        
        Returns
        -------
        term1 : np.array (D, d, D)
            first term of gradient,
            ordered left-mid-right.
        term2 : np.array (D, d, D)
            second term of gradient,
            ordered left-mid-right.
    """
    
    # calculate fixed points if not supplied
    if l is None or r is None:
        l, r = fixedPoints(A)
        
    # calculate first contraction
    term1 = ncon((l, r, A, A, np.conj(A), hTilde), ([-1, 1], [5, 7], [1, 3, 2], [2, 4, 5], [-3, 6, 7], [3, 4, -2, 6]))
    
    # calculate second contraction
    term2 = ncon((l, r, A, A, np.conj(A), hTilde), ([6, 1], [5, -3], [1, 3, 2], [2, 4, 5], [6, 7, -1], [3, 4, 7, -2]))

    
    return term1, term2

# %%
def gradCenterTermsAA(A, l=None, r=None):
    # calculate fixed points if not supplied
    if l is None or r is None:
        l, r = fixedPoints(A)
        
    rhoA = uniformToRho(A)
    
    # calculate first contraction
    term1 = ncon((l, r, A, A, np.conj(A), rhoA), ([-1, 1], [5, 7], [1, 3, 2], [2, 4, 5], [-3, 6, 7], [3, 4, -2, 6]))
        
    # calculate second contraction
    term2 = ncon((l, r, A, A, np.conj(A), rhoA), ([6, 1], [5, -3], [1, 3, 2], [2, 4, 5], [6, 7, -1], [3, 4, 7, -2]))
    
    # calculate the third contraction
    term3 = np.copy(term1)

    # calcualte the fourth contraction
    term4 = np.copy(term2)
    
    return term1, term2, term3, term4

# %%
def reducedHamUniform(h, A, l=None, r=None):
    """
    Regularize Hamiltonian such that its expectation value is 0.
    
        Parameters
        ----------
        h : np.array (d, d, d, d)
            Hamiltonian that needs to be reduced,
            ordered topLeft-topRight-bottomLeft-bottomRight.
        A : np.array (D, d, D)
            normalized MPS tensor with 3 legs,
            ordered left-bottom-right.
        l : np.array (D, D), optional
            left fixed point of transfermatrix,
            normalized.
        r : np.array (D, D), optional
            right fixed point of transfermatrix,
            normalized.
            
        Returns
        -------
        hTilde : np.array (d, d, d, d)
            reduced Hamiltonian,
            ordered topLeft-topRight-bottomLeft-bottomRight.
    """
    
    d = A.shape[1]
    
    # calculate fixed points if not supplied
    if l is None or r is None:
        l, r = fixedPoints(A)
    
    # calculate expectation value
    e = np.real(expVal2Uniform(h, A, l, r))
    
    # substract from hamiltonian
    hTilde = h - e * ncon((np.eye(d), np.eye(d)), ([-1, -3], [-2, -4]))
    
    return hTilde

# %%
def EtildeRight(A, l, r, v):
    """
    Implement the action of (1 - Etilde) on a right vector v.
    
        Parameters
        ----------
        A : np.array (D, d, D)
            normalized MPS tensor with 3 legs,
            ordered left-bottom-right.
        l : np.array (D, D), optional
            left fixed point of transfermatrix,
            normalized.
        r : np.array (D, D), optional
            right fixed point of transfermatrix,
            normalized.
        v : np.array (D**2)
            right matrix of size (D, D) on which
            (1 - Etilde) acts,
            given as a vector of size (D**2,)
        
        Returns
        -------
        vNew : np.array (D**2)
            result of action of (1 - Etilde)
            on a right matrix,
            given as a vector of size (D**2,)
    """
    
    D = A.shape[0]
    
    # reshape to matrix
    v = v.reshape(D, D)
        
    # transfermatrix contribution
    transfer = ncon((A, np.conj(A), v), ([-1, 2, 1], [-2, 2, 3], [1, 3]))

    # fixed point contribution
    fixed = np.trace(l @ v) * r

    # sum these with the contribution of the identity
    vNew = v - transfer + fixed

    return vNew.reshape((D ** 2))

# %%
def RhUniform(hTilde, A, l=None, r=None):
    """
    Find the partial contraction for Rh.
    
        Parameters
        ----------
        hTilde : np.array (d, d, d, d)
            reduced Hamiltonian,
            ordered topLeft-topRight-bottomLeft-bottomRight,
            renormalized.
        A : np.array (D, d, D)
            normalized MPS tensor with 3 legs,
            ordered left-bottom-right.
        l : np.array (D, D), optional
            left fixed point of transfermatrix,
            normalized.
        r : np.array (D, D), optional
            right fixed point of transfermatrix,
            normalized.
        
        Returns
        -------
        Rh : np.array (D, D)
            result of contraction,
            ordered top-bottom.
    """
    
    D = A.shape[0]
    
    # if l, r not specified, find fixed points
    if l is None or r is None:
        l, r = fixedPoints(A)
    
    # construct b, which is the matrix to the right of (1 - E)^P in the figure above
    b = ncon((r, A, A, np.conj(A), np.conj(A), hTilde), ([4, 5], [-1, 2, 1], [1, 3, 4], [-2, 8, 7], [7, 6, 5], [2, 3, 8, 6]))
    
    # solve Ax = b for x
    A = LinearOperator((D ** 2, D ** 2), matvec=partial(EtildeRight, A, l, r))
    Rh = gmres(A, b.reshape(D ** 2))[0]
    
    return Rh.reshape((D, D))

# %%
def gradLeftTerms(hTilde, A, l=None, r=None):
    """
    Calculate the value of the left terms.
    
        Parameters
        ----------
        hTilde : np.array (d, d, d, d)
            reduced Hamiltonian,
            ordered topLeft-topRight-bottomLeft-bottomRight,
            renormalized.
        A : np.array (D, d, D)
            MPS tensor with 3 legs,
            ordered left-bottom-right.
        l : np.array (D, D), optional
            left fixed point of transfermatrix,
            normalized.
        r : np.array (D, D), optional
            right fixed point of transfermatrix,
            normalized.
        
        Returns
        -------
        leftTerms : np.array (D, d, D)
            left terms of gradient,
            ordered left-mid-right.
    """
    
    # if l, r not specified, find fixed points
    if l is None or r is None:
        l, r = fixedPoints(A)
    
    # calculate partial contraction
    Rh = RhUniform(hTilde, A, l, r)
    
    # calculate full contraction
    leftTerms = ncon((Rh, A, l), ([1, -3], [2, -2, 1], [-1, 2]))
    
    return leftTerms

# %%
def EtildeLeft(A, l, r, v):
    """
    Implement the action of (1 - Etilde) on a left vector v.
    
        Parameters
        ----------
        A : np.array (D, d, D)
            normalized MPS tensor with 3 legs,
            ordered left-bottom-right.
        l : np.array (D, D), optional
            left fixed point of transfermatrix,
            normalized.
        r : np.array (D, D), optional
            right fixed point of transfermatrix,
            normalized.
        v : np.array (D**2)
            left matrix of size (D, D) on which
            (1 - Etilde) acts,
            given as a vector of size (D**2,)
        
        Returns
        -------
        vNew : np.array (D**2)
            result of action of (1 - Etilde)
            on a left matrix,
            given as a vector of size (D**2,)
    """
    
    D = A.shape[0]
    
    # reshape to matrix
    v = v.reshape(D, D)

    # transfer matrix contribution
    transfer = ncon((v, A, np.conj(A)), ([3, 1], [1, 2, -2], [3, 2, -1]))

    # fixed point contribution
    fixed = np.trace(v @ r) * l

    # sum these with the contribution of the identity
    vNew = v - transfer + fixed

    return vNew.reshape((D ** 2))

# %%
def LhUniform(hTilde, A, l=None, r=None):
    """
    Find the partial contraction for Lh.
    
        Parameters
        ----------
        hTilde : np.array (d, d, d, d)
            reduced Hamiltonian,
            ordered topLeft-topRight-bottomLeft-bottomRight,
            renormalized.
        A : np.array (D, d, D)
            MPS tensor with 3 legs,
            ordered left-bottom-right.
        l : np.array (D, D), optional
            left fixed point of transfermatrix,
            normalized.
        r : np.array (D, D), optional
            right fixed point of transfermatrix,
            normalized.
        
        Returns
        -------
        Lh : np.array (D, D)
            result of contraction,
            ordered bottom-top.
    """
    
    D = A.shape[0]
    
    # if l, r not specified, find fixed points
    if l is None or r is None:
        l, r = fixedPoints(A)
    
    # construct b, which is the matrix to the right of (1 - E)^P in the figure above
    b = ncon((l, A, A, np.conj(A), np.conj(A), hTilde), ([5, 1], [1, 3, 2], [2, 4, -2], [5, 6, 7], [7, 8, -1], [3, 4, 6, 8]))    
    
    # solve Ax = b for x
    A = LinearOperator((D ** 2, D ** 2), matvec=partial(EtildeLeft, A, l, r)) 
    Lh = gmres(A, b.reshape(D ** 2))[0]
    
    return Lh.reshape((D, D))

# %%
def gradRightTerms(hTilde, A, l=None, r=None):
    """
    Calculate the value of the right terms.
    
        Parameters
        ----------
        hTilde : np.array (d, d, d, d)
            reduced Hamiltonian,
            ordered topLeft-topRight-bottomLeft-bottomRight,
            renormalized.
        A : np.array (D, d, D)
            MPS tensor with 3 legs,
            ordered left-bottom-right.
        l : np.array (D, D), optional
            left fixed point of transfermatrix,
            normalized.
        r : np.array (D, D), optional
            right fixed point of transfermatrix,
            normalized.
        
        Returns
        -------
        rightTerms : np.array (D, d, D)
            right terms of gradient,
            ordered left-mid-right.
    """
    
    # if l, r not specified, find fixed points
    if l is None or r is None:
        l, r = fixedPoints(A)
    
    # calculate partial contraction
    Lh = LhUniform(hTilde, A, l, r)
    
    # calculate full contraction
    rightTerms = ncon((Lh, A, r), ([-1, 1], [1, -2, 2], [2, -3]))
    
    return rightTerms

# %%
def gradient(h, A, l=None, r=None):
    """
    Calculate the gradient of the expectation value of h @ MPS A.
    
        Parameters
        ----------
        h : np.array (d, d, d, d)
            Hamiltonian,
            ordered topLeft-topRight-bottomLeft-bottomRight,
            renormalized.
        A : np.array (D, d, D)
            MPS tensor with 3 legs,
            ordered left-bottom-right.
        l : np.array (D, D), optional
            left fixed point of transfermatrix,
            normalized.
        r : np.array (D, D), optional
            right fixed point of transfermatrix,
            normalized.
        
        Returns
        -------
        grad : np.array (D, d, D)
            Gradient,
            ordered left-mid-right.
    """
    
    # if l, r not specified, find fixed points
    if l is None or r is None:
        l, r = fixedPoints(A)
        
    # prepare rho_A
    rhoA = uniformToRho(A)
        
    # renormalize Hamiltonian and A
    hTilde = reducedHamUniform(h, A, l, r)
    hTildeA = reducedHamUniform(rhoA, A, l, r)
        
    # find terms
    centerTerm1, centerTerm2 = gradCenterTerms(hTilde, A, l, r)
    leftTerms = gradLeftTerms(hTilde, A, l, r)
    rightTerms = gradRightTerms(hTilde, A, l, r)
    
    centerTermAA1, centerTermAA2, centerTermAA3, centerTermAA4 = gradCenterTermsAA(A, l, r)
    leftTermsA = gradLeftTerms(hTildeA, A, l, r)
    rightTermsA = gradRightTerms(hTildeA, A, l, r)
    
    # grad = (centerTerm1A + centerTerm2A + leftTermsA + rightTermsA)
    grad = centerTermAA1 + centerTermAA2 + centerTermAA3 + centerTermAA4 + leftTermsA + rightTermsA
    grad -= 2 * (centerTerm1 + centerTerm2 + leftTerms + rightTerms)
    
    return grad

# %%
def optimiseDensityGradDescent(h, D, eps=1e-1, A0=None, tol=1e-4, maxIter=1e4, verbose=True):
    """
    Find the ground state using gradient descent.
    
        Parameters
        ----------
        h : np.array (d, d, d, d)
            Hamiltonian to minimize,
            ordered topLeft-topRight-bottomLeft-bottomRight.
        D : int
            Bond dimension
        eps : float
            Stepsize.
        A0 : np.array (D, d, D)
            normalized MPS tensor with 3 legs,
            ordered left-bottom-right,
            initial guess.
        tol : float
            Tolerance for convergence criterium.
        
        Returns
        -------
        E : float
            expectation value @ minimum
        A : np.array (D, d, D)
            ground state MPS,
            ordered left-mid-right.
    """
    
    d = h.shape[0]
    
    # if no initial value, choose random
    if A0 is None:
        A0 = createMPS(D, d)
        A0 = normalizeMPS(A0)
    
    # calculate gradient
    g = gradient(h, A0)
    
    A = A0
    
    i = 0
    
    while not(np.linalg.norm(g) < tol):
        # do a step
        A = A - eps * g
        A = normalizeMPS(A)
        i += 1
        
        if verbose and not(i % 50):
            #E = np.real(expVal2Uniform(h, A))
            rhoA = uniformToRho(A)
            E = traceDistance(h, rhoA)
            print('iteration:\t{:d}\tdist:\t{:.12f}\tgradient norm:\t{:.4e}'.format(i, E, np.linalg.norm(g)))
        
        # calculate new gradient
        g = gradient(h, A)
        
        if i > maxIter:
            print('Warning: gradient descent did not converge!')
            break
    
    # calculate ground state energy
    # E = np.real(expVal2Uniform(h, A))
    rhoA = uniformToRho(A)
    E = traceDistance(h, rhoA)   
    
    return E, A

# %%
# Prepare state to optimise
d0, D0 = 2, 2
A0 = createMPS(D0, d0)
A0 = normalizeMPS(A0)

h = uniformToRho(A0)

# %%
d, D = 2, 2
A = createMPS(D, d)
A = normalizeMPS(A)
#A = A0

print('Gradient descent optimization:\n')
t0 = time()
E1, A1 = optimiseDensityGradDescent(h, D, eps=1e-1, A0=A, tol=1e-3, maxIter=1e4)
print('Time until convergence:', time()-t0, 's')
print('Computed energy:', E1, '\n')
# Out:
# Gradient descent optimization:
#
# iteration:	50	dist:	0.741531869109	gradient norm:	2.9730e+00
# iteration:	100	dist:	1.380978042564	gradient norm:	5.7129e+00
# iteration:	150	dist:	0.821434671146	gradient norm:	3.2856e+00
# iteration:	200	dist:	0.772806170183	gradient norm:	3.4203e+00
# iteration:	250	dist:	1.380592137874	gradient norm:	5.4095e+00
# iteration:	300	dist:	0.773084806035	gradient norm:	2.9568e+00
# iteration:	350	dist:	1.139338434415	gradient norm:	3.6704e+00
# iteration:	400	dist:	0.644712065753	gradient norm:	3.6965e+00
# iteration:	450	dist:	0.802474125207	gradient norm:	1.7216e+00
# iteration:	500	dist:	0.473347373064	gradient norm:	5.6599e+00
# iteration:	550	dist:	1.468684276408	gradient norm:	1.1577e+00
# iteration:	600	dist:	0.639294136157	gradient norm:	5.0113e+00
# iteration:	650	dist:	1.391496061028	gradient norm:	1.7556e+00
# iteration:	700	dist:	1.418336217993	gradient norm:	1.8408e+00
# iteration:	750	dist:	1.237878195263	gradient norm:	2.0704e+00
# iteration:	800	dist:	1.635767259984	gradient norm:	3.1376e+00
# iteration:	850	dist:	0.870091655367	gradient norm:	3.0823e+00
# iteration:	900	dist:	0.914908525525	gradient norm:	2.9015e+00
# iteration:	950	dist:	0.766721815337	gradient norm:	3.4061e+00
# iteration:	1000	dist:	1.388118208867	gradient norm:	1.9455e+00
# iteration:	1050	dist:	0.792224267250	gradient norm:	2.7799e+00
# iteration:	1100	dist:	0.870355131091	gradient norm:	2.2961e+00
# iteration:	1150	dist:	0.747152991945	gradient norm:	2.4085e+00
# iteration:	1200	dist:	0.852034737223	gradient norm:	3.0955e+00
# iteration:	1250	dist:	0.907850021789	gradient norm:	2.5235e+00
# iteration:	1300	dist:	1.637906513179	gradient norm:	4.3070e+00
# iteration:	1350	dist:	1.106869311855	gradient norm:	2.7779e+00
# iteration:	1400	dist:	1.138674496895	gradient norm:	2.6329e+00
# iteration:	1450	dist:	1.185103725736	gradient norm:	2.1105e+00
# iteration:	1500	dist:	1.538844813897	gradient norm:	1.2343e+00
# iteration:	1550	dist:	0.659271247440	gradient norm:	1.8265e+00
# iteration:	1600	dist:	1.142690471535	gradient norm:	3.1876e+00
# iteration:	1650	dist:	1.320745812207	gradient norm:	7.7109e+00
# iteration:	1700	dist:	1.261325152063	gradient norm:	3.9137e+00
# iteration:	1750	dist:	1.653014349966	gradient norm:	1.2845e+00
# iteration:	1800	dist:	1.364574413107	gradient norm:	5.2482e+00
# iteration:	1850	dist:	1.029961205838	gradient norm:	3.1987e+00
# iteration:	1900	dist:	1.579617018115	gradient norm:	1.4238e+00
# iteration:	1950	dist:	1.299875262374	gradient norm:	3.4879e+00
# iteration:	2000	dist:	0.895401535817	gradient norm:	3.0434e+00
# iteration:	2050	dist:	1.606367938154	gradient norm:	1.6385e+00
# iteration:	2100	dist:	1.344881122453	gradient norm:	3.8971e+00
# iteration:	2150	dist:	0.819831370314	gradient norm:	6.2102e+00
# iteration:	2200	dist:	1.301599538703	gradient norm:	3.6968e+00
# iteration:	2250	dist:	0.972471305217	gradient norm:	2.4217e+00
# iteration:	2300	dist:	1.163271739574	gradient norm:	4.4933e+00
# iteration:	2350	dist:	0.649735286173	gradient norm:	3.6375e+00
# iteration:	2400	dist:	1.199483766027	gradient norm:	6.7306e+00
# iteration:	2450	dist:	0.396255053975	gradient norm:	3.3056e+00
# iteration:	2500	dist:	0.664669410348	gradient norm:	4.0242e+00
# iteration:	2550	dist:	0.870382111676	gradient norm:	2.5266e+00
# iteration:	2600	dist:	1.337969094595	gradient norm:	4.4494e+00
# iteration:	2650	dist:	1.109736306573	gradient norm:	2.6728e+00
# iteration:	2700	dist:	1.478955544673	gradient norm:	1.9137e+00
# iteration:	2750	dist:	1.640543438058	gradient norm:	4.0026e+00
# iteration:	2800	dist:	0.943076274688	gradient norm:	3.3485e+00
# iteration:	2850	dist:	1.360562454552	gradient norm:	3.5126e+00
# iteration:	2900	dist:	0.656814897549	gradient norm:	2.9912e+00
# iteration:	2950	dist:	1.279985798684	gradient norm:	2.9508e+00
# iteration:	3000	dist:	0.907903187645	gradient norm:	3.3943e+00
# iteration:	3050	dist:	0.904132613789	gradient norm:	3.1473e+00
# iteration:	3100	dist:	0.846650156127	gradient norm:	3.5884e+00
# iteration:	3150	dist:	1.279345011666	gradient norm:	1.5540e+00
# iteration:	3200	dist:	0.556235543423	gradient norm:	2.0786e+00
# iteration:	3250	dist:	0.700740476981	gradient norm:	2.6476e+00
# iteration:	3300	dist:	0.452587051077	gradient norm:	2.1994e+00
# iteration:	3350	dist:	0.814227303440	gradient norm:	2.0667e+00
# iteration:	3400	dist:	0.782002181313	gradient norm:	2.9156e+00
# iteration:	3450	dist:	1.068301356246	gradient norm:	2.5892e+00
# iteration:	3500	dist:	1.235180814310	gradient norm:	3.2721e+00
# iteration:	3550	dist:	1.509368710874	gradient norm:	4.1641e+00
# iteration:	3600	dist:	1.064571162211	gradient norm:	2.5652e+00
# iteration:	3650	dist:	0.910976205984	gradient norm:	2.3808e+00
# iteration:	3700	dist:	0.748739053984	gradient norm:	3.1039e+00
# iteration:	3750	dist:	0.504203689417	gradient norm:	2.1069e+00
# iteration:	3800	dist:	1.197719909756	gradient norm:	2.3041e+00
# iteration:	3850	dist:	1.272889880900	gradient norm:	3.5162e+00
# iteration:	3900	dist:	1.622119452659	gradient norm:	1.7052e+00
# iteration:	3950	dist:	1.627162543459	gradient norm:	2.8181e+00
# iteration:	4000	dist:	0.435164938113	gradient norm:	6.4102e+00
# iteration:	4050	dist:	0.794993511468	gradient norm:	1.9601e+00
# iteration:	4100	dist:	0.755127147666	gradient norm:	3.1041e+00
# iteration:	4150	dist:	1.264061131609	gradient norm:	3.3628e+00
# iteration:	4200	dist:	0.672861011715	gradient norm:	2.2833e+00
# iteration:	4250	dist:	0.629856812751	gradient norm:	1.7669e+00
# iteration:	4300	dist:	0.514542765144	gradient norm:	1.4103e+00
# iteration:	4350	dist:	0.635089457328	gradient norm:	2.4985e+00
# iteration:	4400	dist:	0.552069806552	gradient norm:	2.7448e+00
# iteration:	4450	dist:	0.707941508012	gradient norm:	1.4121e+00
# iteration:	4500	dist:	0.984681932370	gradient norm:	1.1165e+01
# iteration:	4550	dist:	1.106513871109	gradient norm:	2.3624e+00
# iteration:	4600	dist:	1.176006304863	gradient norm:	1.7806e+00
# iteration:	4650	dist:	1.166942247254	gradient norm:	4.3880e+00
# iteration:	4700	dist:	0.489432153431	gradient norm:	1.9481e+00
# iteration:	4750	dist:	0.831002381894	gradient norm:	4.7682e+00
# iteration:	4800	dist:	0.886715374552	gradient norm:	3.4670e+00
# iteration:	4850	dist:	0.703045629580	gradient norm:	2.6718e+00
# iteration:	4900	dist:	0.958605171373	gradient norm:	4.2732e+00
# iteration:	4950	dist:	0.807198828412	gradient norm:	3.4460e+00
# iteration:	5000	dist:	0.725539271934	gradient norm:	1.5480e+00
# iteration:	5050	dist:	1.599647042618	gradient norm:	5.5040e+00
# iteration:	5100	dist:	1.618819591189	gradient norm:	3.4942e+00
# iteration:	5150	dist:	0.749740012778	gradient norm:	1.7671e+00
# iteration:	5200	dist:	0.554283429409	gradient norm:	1.3842e+00
# iteration:	5250	dist:	1.579793004882	gradient norm:	5.2043e+00
# iteration:	5300	dist:	1.067705996864	gradient norm:	4.3337e+00
# iteration:	5350	dist:	0.515995657763	gradient norm:	2.3999e+00
# iteration:	5400	dist:	1.616522175083	gradient norm:	3.3984e+00
# iteration:	5450	dist:	1.006699355928	gradient norm:	2.0097e+00
# iteration:	5500	dist:	1.504948028947	gradient norm:	2.0854e+00
# iteration:	5550	dist:	1.247163341221	gradient norm:	5.5769e+00
# iteration:	5600	dist:	1.233266229317	gradient norm:	2.2400e+00
# iteration:	5650	dist:	0.500336071981	gradient norm:	1.4876e+00
# iteration:	5700	dist:	1.157753600832	gradient norm:	4.5739e+00
# iteration:	5750	dist:	0.840406135759	gradient norm:	3.3170e+00
# iteration:	5800	dist:	0.751548631336	gradient norm:	1.8103e+00
# iteration:	5850	dist:	0.706055683803	gradient norm:	1.5972e+00
# iteration:	5900	dist:	1.206665934121	gradient norm:	2.5464e+00
# iteration:	5950	dist:	1.003950090953	gradient norm:	1.6119e+00
# iteration:	6000	dist:	0.543388012064	gradient norm:	1.3594e+00
# iteration:	6050	dist:	0.472153764892	gradient norm:	2.5204e+00
# iteration:	6100	dist:	0.908863754772	gradient norm:	3.2274e+00
# iteration:	6150	dist:	1.185911171644	gradient norm:	3.2942e+00
# iteration:	6200	dist:	1.351244630569	gradient norm:	3.1778e+00
# iteration:	6250	dist:	0.733808355866	gradient norm:	3.3438e+00
# iteration:	6300	dist:	1.331900779752	gradient norm:	4.2433e+00
# iteration:	6350	dist:	0.995770172691	gradient norm:	1.5294e+00
# iteration:	6400	dist:	0.593909167987	gradient norm:	3.1536e+00
# iteration:	6450	dist:	1.497097384395	gradient norm:	1.4569e+00
# iteration:	6500	dist:	1.217373362874	gradient norm:	1.7515e+00
# iteration:	6550	dist:	1.044667487089	gradient norm:	2.5702e+00
# iteration:	6600	dist:	1.134803103558	gradient norm:	2.7156e+00
# iteration:	6650	dist:	1.383657507081	gradient norm:	3.7558e+00
# iteration:	6700	dist:	1.107696602215	gradient norm:	1.5731e+00
# iteration:	6750	dist:	1.571586443900	gradient norm:	3.5515e+00
# iteration:	6800	dist:	1.143605982737	gradient norm:	3.2788e+00
# iteration:	6850	dist:	1.263609416300	gradient norm:	3.0942e+00
# iteration:	6900	dist:	1.443440108580	gradient norm:	4.7553e+00
# iteration:	6950	dist:	0.981462834600	gradient norm:	9.0386e+00
# iteration:	7000	dist:	0.464247653911	gradient norm:	2.5325e+00
# iteration:	7050	dist:	0.696922423814	gradient norm:	3.1983e+00
# iteration:	7100	dist:	1.410181623480	gradient norm:	5.3531e+00
# iteration:	7150	dist:	0.888536502200	gradient norm:	1.6342e+00
# iteration:	7200	dist:	1.260200840091	gradient norm:	4.0373e+00
# iteration:	7250	dist:	1.426637346159	gradient norm:	4.5173e+00
# iteration:	7300	dist:	1.334452185770	gradient norm:	8.2520e+00
# iteration:	7350	dist:	1.357748671920	gradient norm:	4.3687e+00
# iteration:	7400	dist:	0.403655306821	gradient norm:	3.2738e+00
# iteration:	7450	dist:	1.060152962000	gradient norm:	2.8982e+00
# iteration:	7500	dist:	0.809420264237	gradient norm:	3.3783e+00
# iteration:	7550	dist:	1.504775953918	gradient norm:	4.2720e+00
# iteration:	7600	dist:	0.721368542092	gradient norm:	1.2811e+00
# iteration:	7650	dist:	1.578836662630	gradient norm:	1.3190e+00
# iteration:	7700	dist:	0.953447516180	gradient norm:	2.8065e+00
# iteration:	7750	dist:	0.888944118923	gradient norm:	3.2008e+00
# iteration:	7800	dist:	1.463872492561	gradient norm:	4.1928e+00
# iteration:	7850	dist:	1.057867312953	gradient norm:	2.8604e+00
# iteration:	7900	dist:	1.227643364235	gradient norm:	2.5863e+00
# iteration:	7950	dist:	1.046746833379	gradient norm:	3.2014e+00
# iteration:	8000	dist:	1.358323215149	gradient norm:	1.8882e+00
# iteration:	8050	dist:	0.952770201260	gradient norm:	4.4928e+00
# iteration:	8100	dist:	1.422720836639	gradient norm:	6.0954e+00
# iteration:	8150	dist:	0.401349325360	gradient norm:	1.4698e+00
# iteration:	8200	dist:	0.571552940645	gradient norm:	4.1075e+00
# iteration:	8250	dist:	1.369087054880	gradient norm:	2.0837e+00
# iteration:	8300	dist:	1.614595389254	gradient norm:	1.6392e+00
# iteration:	8350	dist:	0.887762147970	gradient norm:	2.9142e+00
# iteration:	8400	dist:	1.090452974212	gradient norm:	1.8284e+00
# iteration:	8450	dist:	1.220521924622	gradient norm:	2.2745e+00
# iteration:	8500	dist:	1.722129552726	gradient norm:	1.3822e+00
# iteration:	8550	dist:	0.829053375697	gradient norm:	4.5793e+00
# iteration:	8600	dist:	1.647209569930	gradient norm:	1.5806e+00
# iteration:	8650	dist:	0.736774303816	gradient norm:	3.0050e+00
# iteration:	8700	dist:	1.300830993080	gradient norm:	5.5165e+00
# iteration:	8750	dist:	1.234532458310	gradient norm:	3.0862e+00
# iteration:	8800	dist:	1.379030494813	gradient norm:	2.9590e+00
# iteration:	8850	dist:	0.495549982840	gradient norm:	2.2091e+00
# iteration:	8900	dist:	0.526350508867	gradient norm:	3.3683e+00
# iteration:	8950	dist:	1.191483012996	gradient norm:	3.2444e+00
# iteration:	9000	dist:	1.198699213996	gradient norm:	2.1322e+00
# iteration:	9050	dist:	0.745196418505	gradient norm:	3.3774e+00
# iteration:	9100	dist:	1.539933645973	gradient norm:	4.3338e+00
# iteration:	9150	dist:	0.496083766229	gradient norm:	3.1407e+00
# iteration:	9200	dist:	0.871833508072	gradient norm:	2.9129e+00
# iteration:	9250	dist:	1.633307646874	gradient norm:	3.2724e+00
# iteration:	9300	dist:	0.757064171713	gradient norm:	3.7952e+00
# iteration:	9350	dist:	0.463560235602	gradient norm:	3.7090e+00
# iteration:	9400	dist:	1.380653172627	gradient norm:	1.9346e+00
# iteration:	9450	dist:	1.147444020015	gradient norm:	5.0294e+00
# iteration:	9500	dist:	0.725008387977	gradient norm:	3.5763e+00
# iteration:	9550	dist:	1.369355938680	gradient norm:	4.2554e+00
# iteration:	9600	dist:	0.790808097308	gradient norm:	3.4843e+00
# iteration:	9650	dist:	1.400212990207	gradient norm:	2.4032e+00
# iteration:	9700	dist:	0.967141513262	gradient norm:	3.0592e+00
# iteration:	9750	dist:	1.342737228184	gradient norm:	8.9780e+00
# iteration:	9800	dist:	1.105696468167	gradient norm:	3.1440e+00
# iteration:	9850	dist:	1.500546179476	gradient norm:	1.8351e+00
# iteration:	9900	dist:	1.525888670435	gradient norm:	1.1015e+00
# iteration:	9950	dist:	0.882106491589	gradient norm:	5.1126e+00
# iteration:	10000	dist:	0.943459414096	gradient norm:	3.0732e+00
# Warning: gradient descent did not converge!
# Time until convergence: 114.98173809051514 s
# Computed energy: 0.7074302310703011
